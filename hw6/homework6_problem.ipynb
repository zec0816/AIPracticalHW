# %% [markdown]
# ## 作业六——多模态模型
# 本次作业的目的是让同学们体验使用CLIP处理多模态任务，训练一个多模态少样本目标分类模型。
#
# 本次作业需要完成的内容：
# 1. 仔细阅读代码，补全TODO(1)~TODO(3)标记的内容
#
# 需要提交的内容
# - 补全后的代码。
# - 实验报告（一个PDF文件），要求记录实验准确率，并作简要分析总结。
#
# **请注意，提交的.ipynb文件需要能够重启kernel后，通过一次 全部运行 复现出所有的实验结果。请同学们在提交前按这种方式进行一次检查。**
# 有随机性的部分复现结果存在一些差别是允许的，但请至少保证不要相差太远，保证代码可以正常执行。

# %%
import jittor as jt
from jittor import nn
from jittor.transform import CenterCrop, ImageNormalize, Compose, resize
from PIL import Image
import os
from tqdm import tqdm
from sklearn.linear_model import LogisticRegression
import numpy as np
from typing import Union, Tuple, List, Optional
import gzip
import html
import os
from functools import partial

from jittor import Var
from jittor.nn import Module, Linear, softmax, linear, matmul_transpose
from jittor.dataset import Dataset

import ftfy
import regex as re
import math

jt.flags.use_cuda = 1
# Out:
# [i 1229 13:26:32.296452 12 cuda_flags.cc:55] CUDA enabled.

# %%
# 如果使用 vGPU，那已经下载好了，无需重复下载；否则需要自己下载
# !wget -O bpe_simple_vocab_16e6.txt.gz "https://cloud.tsinghua.edu.cn/f/a65c412d818d4e46bd42/?dl=1"
# !wget -O dataset.zip "https://cloud.tsinghua.edu.cn/f/1550782fa0f346028a82/?dl=1"
# !unzip dataset.zip
# !wget -O ViT-B-32.pkl "https://cloud.tsinghua.edu.cn/f/860a9afb257f4d5180be/?dl=1"
# Out:
# --2025-12-29 13:26:55--  https://cloud.tsinghua.edu.cn/f/a65c412d818d4e46bd42/?dl=1
# Resolving cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)... 101.6.15.69, 2402:f000:1:402:101:6:15:69
# Connecting to cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)|101.6.15.69|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cloud.tsinghua.edu.cn/seafhttp/files/16fa6b3f-7e3b-4b55-a2dc-c8faf99726d9/bpe_simple_vocab_16e6.txt.gz [following]
# --2025-12-29 13:26:55--  https://cloud.tsinghua.edu.cn/seafhttp/files/16fa6b3f-7e3b-4b55-a2dc-c8faf99726d9/bpe_simple_vocab_16e6.txt.gz
# Reusing existing connection to cloud.tsinghua.edu.cn:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1356917 (1.3M) [application/octet-stream]
# Saving to: ‘bpe_simple_vocab_16e6.txt.gz’
#
# bpe_simple_vocab_16 100%[===================>]   1.29M  6.41MB/s    in 0.2s
#
# 2025-12-29 13:26:55 (6.41 MB/s) - ‘bpe_simple_vocab_16e6.txt.gz’ saved [1356917/1356917]
#
# --2025-12-29 13:26:56--  https://cloud.tsinghua.edu.cn/f/1550782fa0f346028a82/?dl=1
# Resolving cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)... 101.6.15.69, 2402:f000:1:402:101:6:15:69
# Connecting to cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)|101.6.15.69|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cloud.tsinghua.edu.cn/seafhttp/files/904b56ca-f8fd-44bd-a052-cca7d14d73dc/dataset.zip [following]
# --2025-12-29 13:26:56--  https://cloud.tsinghua.edu.cn/seafhttp/files/904b56ca-f8fd-44bd-a052-cca7d14d73dc/dataset.zip
# Reusing existing connection to cloud.tsinghua.edu.cn:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 310234644 (296M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>] 295.86M  2.98MB/s    in 1m 40s
#
# 2025-12-29 13:28:36 (2.96 MB/s) - ‘dataset.zip’ saved [310234644/310234644]
#
# Archive:  dataset.zip
#   inflating: classes.txt
#    creating: Dataset/
#   inflating: Dataset/classes.txt
#    creating: Dataset/Images/
#    creating: Dataset/Images/0/
#   inflating: Dataset/Images/0/1.jpg
#   inflating: Dataset/Images/0/10.jpg
#   inflating: Dataset/Images/0/11.jpg
#   inflating: Dataset/Images/0/12.jpg
#   inflating: Dataset/Images/0/13.jpg
#   inflating: Dataset/Images/0/14.jpg
#   inflating: Dataset/Images/0/2.jpg
#   inflating: Dataset/Images/0/3.jpg
#   inflating: Dataset/Images/0/4.jpg
#   inflating: Dataset/Images/0/5.jpg
#   inflating: Dataset/Images/0/6.jpg
#   inflating: Dataset/Images/0/7.jpg
#   inflating: Dataset/Images/0/8.jpg
#   inflating: Dataset/Images/0/9.jpg
#    creating: Dataset/Images/1/
#   inflating: Dataset/Images/1/1.jpg
#   inflating: Dataset/Images/1/10.jpg
#   inflating: Dataset/Images/1/11.jpg
#   inflating: Dataset/Images/1/12.jpg
#   inflating: Dataset/Images/1/13.jpg
#   inflating: Dataset/Images/1/14.jpg
#   inflating: Dataset/Images/1/2.jpg
#   inflating: Dataset/Images/1/3.jpg
#   inflating: Dataset/Images/1/4.jpg
#   inflating: Dataset/Images/1/5.jpg
#   inflating: Dataset/Images/1/6.jpg
#   inflating: Dataset/Images/1/7.jpg
#   inflating: Dataset/Images/1/8.jpg
#   inflating: Dataset/Images/1/9.jpg
#    creating: Dataset/Images/10/
#   inflating: Dataset/Images/10/1.jpg
#   inflating: Dataset/Images/10/10.jpg
#   inflating: Dataset/Images/10/11.jpg
#   inflating: Dataset/Images/10/12.jpg
#   inflating: Dataset/Images/10/13.jpg
#   inflating: Dataset/Images/10/14.jpg
#   inflating: Dataset/Images/10/2.jpg
#   inflating: Dataset/Images/10/3.jpg
#   inflating: Dataset/Images/10/4.jpg
#   inflating: Dataset/Images/10/5.jpg
#   inflating: Dataset/Images/10/6.jpg
#   inflating: Dataset/Images/10/7.jpg
#   inflating: Dataset/Images/10/8.jpg
#   inflating: Dataset/Images/10/9.jpg
#    creating: Dataset/Images/100/
#   inflating: Dataset/Images/100/1.jpg
#   inflating: Dataset/Images/100/10.jpg
#   inflating: Dataset/Images/100/11.jpg
#   inflating: Dataset/Images/100/12.jpg
#   inflating: Dataset/Images/100/13.jpg
#   inflating: Dataset/Images/100/14.jpg
#   inflating: Dataset/Images/100/2.jpg
#   inflating: Dataset/Images/100/3.jpg
#   inflating: Dataset/Images/100/4.jpg
#   inflating: Dataset/Images/100/5.jpg
#   inflating: Dataset/Images/100/6.jpg
#   inflating: Dataset/Images/100/7.jpg
#   inflating: Dataset/Images/100/8.jpg
#   inflating: Dataset/Images/100/9.jpg
#    creating: Dataset/Images/101/
#   inflating: Dataset/Images/101/1.jpg
#   inflating: Dataset/Images/101/10.jpg
#   inflating: Dataset/Images/101/11.jpg
#   inflating: Dataset/Images/101/12.jpg
#   inflating: Dataset/Images/101/13.jpg
#   inflating: Dataset/Images/101/14.jpg
#   inflating: Dataset/Images/101/2.jpg
#   inflating: Dataset/Images/101/3.jpg
#   inflating: Dataset/Images/101/4.jpg
#   inflating: Dataset/Images/101/5.jpg
#   inflating: Dataset/Images/101/6.jpg
#   inflating: Dataset/Images/101/7.jpg
#   inflating: Dataset/Images/101/8.jpg
#   inflating: Dataset/Images/101/9.jpg
#    creating: Dataset/Images/102/
#   inflating: Dataset/Images/102/1.jpg
#   inflating: Dataset/Images/102/10.jpg
#   inflating: Dataset/Images/102/11.jpg
#   inflating: Dataset/Images/102/12.jpg
#   inflating: Dataset/Images/102/13.jpg
#   inflating: Dataset/Images/102/14.jpg
#   inflating: Dataset/Images/102/2.jpg
#   inflating: Dataset/Images/102/3.jpg
#   inflating: Dataset/Images/102/4.jpg
#   inflating: Dataset/Images/102/5.jpg
#   inflating: Dataset/Images/102/6.jpg
#   inflating: Dataset/Images/102/7.jpg
#   inflating: Dataset/Images/102/8.jpg
#   inflating: Dataset/Images/102/9.jpg
#    creating: Dataset/Images/103/
#   inflating: Dataset/Images/103/1.jpg
#   inflating: Dataset/Images/103/10.jpg
#   inflating: Dataset/Images/103/11.jpg
#   inflating: Dataset/Images/103/12.jpg
#   inflating: Dataset/Images/103/13.jpg
#   inflating: Dataset/Images/103/14.jpg
#   inflating: Dataset/Images/103/2.jpg
#   inflating: Dataset/Images/103/3.jpg
#   inflating: Dataset/Images/103/4.jpg
#   inflating: Dataset/Images/103/5.jpg
#   inflating: Dataset/Images/103/6.jpg
#   inflating: Dataset/Images/103/7.jpg
#   inflating: Dataset/Images/103/8.jpg
#   inflating: Dataset/Images/103/9.jpg
#    creating: Dataset/Images/104/
#   inflating: Dataset/Images/104/1.jpg
#   inflating: Dataset/Images/104/10.jpg
#   inflating: Dataset/Images/104/11.jpg
#   inflating: Dataset/Images/104/12.jpg
#   inflating: Dataset/Images/104/13.jpg
#   inflating: Dataset/Images/104/14.jpg
#   inflating: Dataset/Images/104/2.jpg
#   inflating: Dataset/Images/104/3.jpg
#   inflating: Dataset/Images/104/4.jpg
#   inflating: Dataset/Images/104/5.jpg
#   inflating: Dataset/Images/104/6.jpg
#   inflating: Dataset/Images/104/7.jpg
#   inflating: Dataset/Images/104/8.jpg
#   inflating: Dataset/Images/104/9.jpg
#    creating: Dataset/Images/105/
#   inflating: Dataset/Images/105/1.jpg
#   inflating: Dataset/Images/105/10.jpg
#   inflating: Dataset/Images/105/11.jpg
#   inflating: Dataset/Images/105/12.jpg
#   inflating: Dataset/Images/105/13.jpg
#   inflating: Dataset/Images/105/14.jpg
#   inflating: Dataset/Images/105/2.jpg
#   inflating: Dataset/Images/105/3.jpg
#   inflating: Dataset/Images/105/4.jpg
#   inflating: Dataset/Images/105/5.jpg
#   inflating: Dataset/Images/105/6.jpg
#   inflating: Dataset/Images/105/7.jpg
#   inflating: Dataset/Images/105/8.jpg
#   inflating: Dataset/Images/105/9.jpg
#    creating: Dataset/Images/106/
#   inflating: Dataset/Images/106/1.jpg
#   inflating: Dataset/Images/106/10.jpg
#   inflating: Dataset/Images/106/11.jpg
#   inflating: Dataset/Images/106/12.jpg
#   inflating: Dataset/Images/106/13.jpg
#   inflating: Dataset/Images/106/14.jpg
#   inflating: Dataset/Images/106/2.jpg
#   inflating: Dataset/Images/106/3.jpg
#   inflating: Dataset/Images/106/4.jpg
#   inflating: Dataset/Images/106/5.jpg
#   inflating: Dataset/Images/106/6.jpg
#   inflating: Dataset/Images/106/7.jpg
#   inflating: Dataset/Images/106/8.jpg
#   inflating: Dataset/Images/106/9.jpg
#    creating: Dataset/Images/107/
#   inflating: Dataset/Images/107/1.jpg
#   inflating: Dataset/Images/107/10.jpg
#   inflating: Dataset/Images/107/11.jpg
#   inflating: Dataset/Images/107/12.jpg
#   inflating: Dataset/Images/107/13.jpg
#   inflating: Dataset/Images/107/14.jpg
#   inflating: Dataset/Images/107/2.jpg
#   inflating: Dataset/Images/107/3.jpg
#   inflating: Dataset/Images/107/4.jpg
#   inflating: Dataset/Images/107/5.jpg
#   inflating: Dataset/Images/107/6.jpg
#   inflating: Dataset/Images/107/7.jpg
#   inflating: Dataset/Images/107/8.jpg
#   inflating: Dataset/Images/107/9.jpg
#    creating: Dataset/Images/108/
#   inflating: Dataset/Images/108/1.jpg
#   inflating: Dataset/Images/108/10.jpg
#   inflating: Dataset/Images/108/11.jpg
#   inflating: Dataset/Images/108/12.jpg
#   inflating: Dataset/Images/108/13.jpg
#   inflating: Dataset/Images/108/14.jpg
#   inflating: Dataset/Images/108/2.jpg
#   inflating: Dataset/Images/108/3.jpg
#   inflating: Dataset/Images/108/4.jpg
#   inflating: Dataset/Images/108/5.jpg
#   inflating: Dataset/Images/108/6.jpg
#   inflating: Dataset/Images/108/7.jpg
#   inflating: Dataset/Images/108/8.jpg
#   inflating: Dataset/Images/108/9.jpg
#    creating: Dataset/Images/109/
#   inflating: Dataset/Images/109/1.jpg
#   inflating: Dataset/Images/109/10.jpg
#   inflating: Dataset/Images/109/11.jpg
#   inflating: Dataset/Images/109/12.jpg
#   inflating: Dataset/Images/109/13.jpg
#   inflating: Dataset/Images/109/14.jpg
#   inflating: Dataset/Images/109/2.jpg
#   inflating: Dataset/Images/109/3.jpg
#   inflating: Dataset/Images/109/4.jpg
#   inflating: Dataset/Images/109/5.jpg
#   inflating: Dataset/Images/109/6.jpg
#   inflating: Dataset/Images/109/7.jpg
#   inflating: Dataset/Images/109/8.jpg
#   inflating: Dataset/Images/109/9.jpg
#    creating: Dataset/Images/11/
#   inflating: Dataset/Images/11/1.jpg
#   inflating: Dataset/Images/11/10.jpg
#   inflating: Dataset/Images/11/11.jpg
#   inflating: Dataset/Images/11/12.jpg
#   inflating: Dataset/Images/11/13.jpg
#   inflating: Dataset/Images/11/14.jpg
#   inflating: Dataset/Images/11/2.jpg
#   inflating: Dataset/Images/11/3.jpg
#   inflating: Dataset/Images/11/4.jpg
#   inflating: Dataset/Images/11/5.jpg
#   inflating: Dataset/Images/11/6.jpg
#   inflating: Dataset/Images/11/7.jpg
#   inflating: Dataset/Images/11/8.jpg
#   inflating: Dataset/Images/11/9.jpg
#    creating: Dataset/Images/110/
#   inflating: Dataset/Images/110/1.jpg
#   inflating: Dataset/Images/110/10.jpg
#   inflating: Dataset/Images/110/11.jpg
#   inflating: Dataset/Images/110/12.jpg
#   inflating: Dataset/Images/110/13.jpg
#   inflating: Dataset/Images/110/14.jpg
#   inflating: Dataset/Images/110/2.jpg
#   inflating: Dataset/Images/110/3.jpg
#   inflating: Dataset/Images/110/4.jpg
#   inflating: Dataset/Images/110/5.jpg
#   inflating: Dataset/Images/110/6.jpg
#   inflating: Dataset/Images/110/7.jpg
#   inflating: Dataset/Images/110/8.jpg
#   inflating: Dataset/Images/110/9.jpg
#    creating: Dataset/Images/111/
#   inflating: Dataset/Images/111/1.jpg
#   inflating: Dataset/Images/111/10.jpg
#   inflating: Dataset/Images/111/11.jpg
#   inflating: Dataset/Images/111/12.jpg
#   inflating: Dataset/Images/111/13.jpg
#   inflating: Dataset/Images/111/14.jpg
#   inflating: Dataset/Images/111/2.jpg
#   inflating: Dataset/Images/111/3.jpg
#   inflating: Dataset/Images/111/4.jpg
#   inflating: Dataset/Images/111/5.jpg
#   inflating: Dataset/Images/111/6.jpg
#   inflating: Dataset/Images/111/7.jpg
#   inflating: Dataset/Images/111/8.jpg
#   inflating: Dataset/Images/111/9.jpg
#    creating: Dataset/Images/112/
#   inflating: Dataset/Images/112/1.jpg
#   inflating: Dataset/Images/112/10.jpg
#   inflating: Dataset/Images/112/11.jpg
#   inflating: Dataset/Images/112/12.jpg
#   inflating: Dataset/Images/112/13.jpg
#   inflating: Dataset/Images/112/14.jpg
#   inflating: Dataset/Images/112/2.jpg
#   inflating: Dataset/Images/112/3.jpg
#   inflating: Dataset/Images/112/4.jpg
#   inflating: Dataset/Images/112/5.jpg
#   inflating: Dataset/Images/112/6.jpg
#   inflating: Dataset/Images/112/7.jpg
#   inflating: Dataset/Images/112/8.jpg
#   inflating: Dataset/Images/112/9.jpg
#    creating: Dataset/Images/113/
#   inflating: Dataset/Images/113/1.jpg
#   inflating: Dataset/Images/113/10.jpg
#   inflating: Dataset/Images/113/11.jpg
#   inflating: Dataset/Images/113/12.jpg
#   inflating: Dataset/Images/113/13.jpg
#   inflating: Dataset/Images/113/14.jpg
#   inflating: Dataset/Images/113/2.jpg
#   inflating: Dataset/Images/113/3.jpg
#   inflating: Dataset/Images/113/4.jpg
#   inflating: Dataset/Images/113/5.jpg
#   inflating: Dataset/Images/113/6.jpg
#   inflating: Dataset/Images/113/7.jpg
#   inflating: Dataset/Images/113/8.jpg
#   inflating: Dataset/Images/113/9.jpg
#    creating: Dataset/Images/114/
#   inflating: Dataset/Images/114/1.jpg
#   inflating: Dataset/Images/114/10.jpg
#   inflating: Dataset/Images/114/11.jpg
#   inflating: Dataset/Images/114/12.jpg
#   inflating: Dataset/Images/114/13.jpg
#   inflating: Dataset/Images/114/14.jpg
#   inflating: Dataset/Images/114/2.jpg
#   inflating: Dataset/Images/114/3.jpg
#   inflating: Dataset/Images/114/4.jpg
#   inflating: Dataset/Images/114/5.jpg
#   inflating: Dataset/Images/114/6.jpg
#   inflating: Dataset/Images/114/7.jpg
#   inflating: Dataset/Images/114/8.jpg
#   inflating: Dataset/Images/114/9.jpg
#    creating: Dataset/Images/115/
#   inflating: Dataset/Images/115/1.jpg
#   inflating: Dataset/Images/115/10.jpg
#   inflating: Dataset/Images/115/11.jpg
#   inflating: Dataset/Images/115/12.jpg
#   inflating: Dataset/Images/115/13.jpg
#   inflating: Dataset/Images/115/14.jpg
#   inflating: Dataset/Images/115/2.jpg
#   inflating: Dataset/Images/115/3.jpg
#   inflating: Dataset/Images/115/4.jpg
#   inflating: Dataset/Images/115/5.jpg
#   inflating: Dataset/Images/115/6.jpg
#   inflating: Dataset/Images/115/7.jpg
#   inflating: Dataset/Images/115/8.jpg
#   inflating: Dataset/Images/115/9.jpg
#    creating: Dataset/Images/116/
#   inflating: Dataset/Images/116/1.jpg
#   inflating: Dataset/Images/116/10.jpg
#   inflating: Dataset/Images/116/11.jpg
#   inflating: Dataset/Images/116/12.jpg
#   inflating: Dataset/Images/116/13.jpg
#   inflating: Dataset/Images/116/14.jpg
#   inflating: Dataset/Images/116/2.jpg
#   inflating: Dataset/Images/116/3.jpg
#   inflating: Dataset/Images/116/4.jpg
#   inflating: Dataset/Images/116/5.jpg
#   inflating: Dataset/Images/116/6.jpg
#   inflating: Dataset/Images/116/7.jpg
#   inflating: Dataset/Images/116/8.jpg
#   inflating: Dataset/Images/116/9.jpg
#    creating: Dataset/Images/117/
#   inflating: Dataset/Images/117/1.jpg
#   inflating: Dataset/Images/117/10.jpg
#   inflating: Dataset/Images/117/11.jpg
#   inflating: Dataset/Images/117/12.jpg
#   inflating: Dataset/Images/117/13.jpg
#   inflating: Dataset/Images/117/14.jpg
#   inflating: Dataset/Images/117/2.jpg
#   inflating: Dataset/Images/117/3.jpg
#   inflating: Dataset/Images/117/4.jpg
#   inflating: Dataset/Images/117/5.jpg
#   inflating: Dataset/Images/117/6.jpg
#   inflating: Dataset/Images/117/7.jpg
#   inflating: Dataset/Images/117/8.jpg
#   inflating: Dataset/Images/117/9.jpg
#    creating: Dataset/Images/118/
#   inflating: Dataset/Images/118/1.jpg
#   inflating: Dataset/Images/118/10.jpg
#   inflating: Dataset/Images/118/11.jpg
#   inflating: Dataset/Images/118/12.jpg
#   inflating: Dataset/Images/118/13.jpg
#   inflating: Dataset/Images/118/14.jpg
#   inflating: Dataset/Images/118/2.jpg
#   inflating: Dataset/Images/118/3.jpg
#   inflating: Dataset/Images/118/4.jpg
#   inflating: Dataset/Images/118/5.jpg
#   inflating: Dataset/Images/118/6.jpg
#   inflating: Dataset/Images/118/7.jpg
#   inflating: Dataset/Images/118/8.jpg
#   inflating: Dataset/Images/118/9.jpg
#    creating: Dataset/Images/119/
#   inflating: Dataset/Images/119/1.jpg
#   inflating: Dataset/Images/119/10.jpg
#   inflating: Dataset/Images/119/11.jpg
#   inflating: Dataset/Images/119/12.jpg
#   inflating: Dataset/Images/119/13.jpg
#   inflating: Dataset/Images/119/14.jpg
#   inflating: Dataset/Images/119/2.jpg
#   inflating: Dataset/Images/119/3.jpg
#   inflating: Dataset/Images/119/4.jpg
#   inflating: Dataset/Images/119/5.jpg
#   inflating: Dataset/Images/119/6.jpg
#   inflating: Dataset/Images/119/7.jpg
#   inflating: Dataset/Images/119/8.jpg
#   inflating: Dataset/Images/119/9.jpg
#    creating: Dataset/Images/12/
#   inflating: Dataset/Images/12/1.jpg
#   inflating: Dataset/Images/12/10.jpg
#   inflating: Dataset/Images/12/11.jpg
#   inflating: Dataset/Images/12/12.jpg
#   inflating: Dataset/Images/12/13.jpg
#   inflating: Dataset/Images/12/14.jpg
#   inflating: Dataset/Images/12/2.jpg
#   inflating: Dataset/Images/12/3.jpg
#   inflating: Dataset/Images/12/4.jpg
#   inflating: Dataset/Images/12/5.jpg
#   inflating: Dataset/Images/12/6.jpg
#   inflating: Dataset/Images/12/7.jpg
#   inflating: Dataset/Images/12/8.jpg
#   inflating: Dataset/Images/12/9.jpg
#    creating: Dataset/Images/120/
#   inflating: Dataset/Images/120/1.jpg
#   inflating: Dataset/Images/120/10.jpg
#   inflating: Dataset/Images/120/11.jpg
#   inflating: Dataset/Images/120/12.jpg
#   inflating: Dataset/Images/120/13.jpg
#   inflating: Dataset/Images/120/14.jpg
#   inflating: Dataset/Images/120/2.jpg
#   inflating: Dataset/Images/120/3.jpg
#   inflating: Dataset/Images/120/4.jpg
#   inflating: Dataset/Images/120/5.jpg
#   inflating: Dataset/Images/120/6.jpg
#   inflating: Dataset/Images/120/7.jpg
#   inflating: Dataset/Images/120/8.jpg
#   inflating: Dataset/Images/120/9.jpg
#    creating: Dataset/Images/121/
#   inflating: Dataset/Images/121/1.jpg
#   inflating: Dataset/Images/121/10.jpg
#   inflating: Dataset/Images/121/11.jpg
#   inflating: Dataset/Images/121/12.jpg
#   inflating: Dataset/Images/121/13.jpg
#   inflating: Dataset/Images/121/14.jpg
#   inflating: Dataset/Images/121/2.jpg
#   inflating: Dataset/Images/121/3.jpg
#   inflating: Dataset/Images/121/4.jpg
#   inflating: Dataset/Images/121/5.jpg
#   inflating: Dataset/Images/121/6.jpg
#   inflating: Dataset/Images/121/7.jpg
#   inflating: Dataset/Images/121/8.jpg
#   inflating: Dataset/Images/121/9.jpg
#    creating: Dataset/Images/122/
#   inflating: Dataset/Images/122/1.jpg
#   inflating: Dataset/Images/122/10.jpg
#   inflating: Dataset/Images/122/11.jpg
#   inflating: Dataset/Images/122/12.jpg
#   inflating: Dataset/Images/122/13.jpg
#   inflating: Dataset/Images/122/14.jpg
#   inflating: Dataset/Images/122/2.jpg
#   inflating: Dataset/Images/122/3.jpg
#   inflating: Dataset/Images/122/4.jpg
#   inflating: Dataset/Images/122/5.jpg
#   inflating: Dataset/Images/122/6.jpg
#   inflating: Dataset/Images/122/7.jpg
#   inflating: Dataset/Images/122/8.jpg
#   inflating: Dataset/Images/122/9.jpg
#    creating: Dataset/Images/123/
#   inflating: Dataset/Images/123/1.jpg
#   inflating: Dataset/Images/123/10.jpg
#   inflating: Dataset/Images/123/11.jpg
#   inflating: Dataset/Images/123/12.jpg
#   inflating: Dataset/Images/123/13.jpg
#   inflating: Dataset/Images/123/14.jpg
#   inflating: Dataset/Images/123/2.jpg
#   inflating: Dataset/Images/123/3.jpg
#   inflating: Dataset/Images/123/4.jpg
#   inflating: Dataset/Images/123/5.jpg
#   inflating: Dataset/Images/123/6.jpg
#   inflating: Dataset/Images/123/7.jpg
#   inflating: Dataset/Images/123/8.jpg
#   inflating: Dataset/Images/123/9.jpg
#    creating: Dataset/Images/124/
#   inflating: Dataset/Images/124/1.jpg
#   inflating: Dataset/Images/124/10.jpg
#   inflating: Dataset/Images/124/11.jpg
#   inflating: Dataset/Images/124/12.jpg
#   inflating: Dataset/Images/124/13.jpg
#   inflating: Dataset/Images/124/14.jpg
#   inflating: Dataset/Images/124/2.jpg
#   inflating: Dataset/Images/124/3.jpg
#   inflating: Dataset/Images/124/4.jpg
#   inflating: Dataset/Images/124/5.jpg
#   inflating: Dataset/Images/124/6.jpg
#   inflating: Dataset/Images/124/7.jpg
#   inflating: Dataset/Images/124/8.jpg
#   inflating: Dataset/Images/124/9.jpg
#    creating: Dataset/Images/125/
#   inflating: Dataset/Images/125/1.jpg
#   inflating: Dataset/Images/125/10.jpg
#   inflating: Dataset/Images/125/11.jpg
#   inflating: Dataset/Images/125/12.jpg
#   inflating: Dataset/Images/125/13.jpg
#   inflating: Dataset/Images/125/14.jpg
#   inflating: Dataset/Images/125/2.jpg
#   inflating: Dataset/Images/125/3.jpg
#   inflating: Dataset/Images/125/4.jpg
#   inflating: Dataset/Images/125/5.jpg
#   inflating: Dataset/Images/125/6.jpg
#   inflating: Dataset/Images/125/7.jpg
#   inflating: Dataset/Images/125/8.jpg
#   inflating: Dataset/Images/125/9.jpg
#    creating: Dataset/Images/126/
#   inflating: Dataset/Images/126/1.jpg
#   inflating: Dataset/Images/126/10.jpg
#   inflating: Dataset/Images/126/11.jpg
#   inflating: Dataset/Images/126/12.jpg
#   inflating: Dataset/Images/126/13.jpg
#   inflating: Dataset/Images/126/14.jpg
#   inflating: Dataset/Images/126/2.jpg
#   inflating: Dataset/Images/126/3.jpg
#   inflating: Dataset/Images/126/4.jpg
#   inflating: Dataset/Images/126/5.jpg
#   inflating: Dataset/Images/126/6.jpg
#   inflating: Dataset/Images/126/7.jpg
#   inflating: Dataset/Images/126/8.jpg
#   inflating: Dataset/Images/126/9.jpg
#    creating: Dataset/Images/127/
#   inflating: Dataset/Images/127/1.jpg
#   inflating: Dataset/Images/127/10.jpg
#   inflating: Dataset/Images/127/11.jpg
#   inflating: Dataset/Images/127/12.jpg
#   inflating: Dataset/Images/127/13.jpg
#   inflating: Dataset/Images/127/14.jpg
#   inflating: Dataset/Images/127/2.jpg
#   inflating: Dataset/Images/127/3.jpg
#   inflating: Dataset/Images/127/4.jpg
#   inflating: Dataset/Images/127/5.jpg
#   inflating: Dataset/Images/127/6.jpg
#   inflating: Dataset/Images/127/7.jpg
#   inflating: Dataset/Images/127/8.jpg
#   inflating: Dataset/Images/127/9.jpg
#    creating: Dataset/Images/128/
#   inflating: Dataset/Images/128/1.jpg
#   inflating: Dataset/Images/128/10.jpg
#   inflating: Dataset/Images/128/11.jpg
#   inflating: Dataset/Images/128/12.jpg
#   inflating: Dataset/Images/128/13.jpg
#   inflating: Dataset/Images/128/14.jpg
#   inflating: Dataset/Images/128/2.jpg
#   inflating: Dataset/Images/128/3.jpg
#   inflating: Dataset/Images/128/4.jpg
#   inflating: Dataset/Images/128/5.jpg
#   inflating: Dataset/Images/128/6.jpg
#   inflating: Dataset/Images/128/7.jpg
#   inflating: Dataset/Images/128/8.jpg
#   inflating: Dataset/Images/128/9.jpg
#    creating: Dataset/Images/129/
#   inflating: Dataset/Images/129/1.jpg
#   inflating: Dataset/Images/129/10.jpg
#   inflating: Dataset/Images/129/11.jpg
#   inflating: Dataset/Images/129/12.jpg
#   inflating: Dataset/Images/129/13.jpg
#   inflating: Dataset/Images/129/14.jpg
#   inflating: Dataset/Images/129/2.jpg
#   inflating: Dataset/Images/129/3.jpg
#   inflating: Dataset/Images/129/4.jpg
#   inflating: Dataset/Images/129/5.jpg
#   inflating: Dataset/Images/129/6.jpg
#   inflating: Dataset/Images/129/7.jpg
#   inflating: Dataset/Images/129/8.jpg
#   inflating: Dataset/Images/129/9.jpg
#    creating: Dataset/Images/13/
#   inflating: Dataset/Images/13/1.jpg
#   inflating: Dataset/Images/13/10.jpg
#   inflating: Dataset/Images/13/11.jpg
#   inflating: Dataset/Images/13/12.jpg
#   inflating: Dataset/Images/13/13.jpg
#   inflating: Dataset/Images/13/14.jpg
#   inflating: Dataset/Images/13/2.jpg
#   inflating: Dataset/Images/13/3.jpg
#   inflating: Dataset/Images/13/4.jpg
#   inflating: Dataset/Images/13/5.jpg
#   inflating: Dataset/Images/13/6.jpg
#   inflating: Dataset/Images/13/7.jpg
#   inflating: Dataset/Images/13/8.jpg
#   inflating: Dataset/Images/13/9.jpg
#    creating: Dataset/Images/130/
#   inflating: Dataset/Images/130/1.jpg
#   inflating: Dataset/Images/130/10.jpg
#   inflating: Dataset/Images/130/11.jpg
#   inflating: Dataset/Images/130/12.jpg
#   inflating: Dataset/Images/130/13.jpg
#   inflating: Dataset/Images/130/14.jpg
#   inflating: Dataset/Images/130/2.jpg
#   inflating: Dataset/Images/130/3.jpg
#   inflating: Dataset/Images/130/4.jpg
#   inflating: Dataset/Images/130/5.jpg
#   inflating: Dataset/Images/130/6.jpg
#   inflating: Dataset/Images/130/7.jpg
#   inflating: Dataset/Images/130/8.jpg
#   inflating: Dataset/Images/130/9.jpg
#    creating: Dataset/Images/131/
#   inflating: Dataset/Images/131/1.jpg
#   inflating: Dataset/Images/131/10.jpg
#   inflating: Dataset/Images/131/11.jpg
#   inflating: Dataset/Images/131/12.jpg
#   inflating: Dataset/Images/131/13.jpg
#   inflating: Dataset/Images/131/14.jpg
#   inflating: Dataset/Images/131/2.jpg
#   inflating: Dataset/Images/131/3.jpg
#   inflating: Dataset/Images/131/4.jpg
#   inflating: Dataset/Images/131/5.jpg
#   inflating: Dataset/Images/131/6.jpg
#   inflating: Dataset/Images/131/7.jpg
#   inflating: Dataset/Images/131/8.jpg
#   inflating: Dataset/Images/131/9.jpg
#    creating: Dataset/Images/132/
#   inflating: Dataset/Images/132/1.jpg
#   inflating: Dataset/Images/132/10.jpg
#   inflating: Dataset/Images/132/11.jpg
#   inflating: Dataset/Images/132/12.jpg
#   inflating: Dataset/Images/132/13.jpg
#   inflating: Dataset/Images/132/14.jpg
#   inflating: Dataset/Images/132/2.jpg
#   inflating: Dataset/Images/132/3.jpg
#   inflating: Dataset/Images/132/4.jpg
#   inflating: Dataset/Images/132/5.jpg
#   inflating: Dataset/Images/132/6.jpg
#   inflating: Dataset/Images/132/7.jpg
#   inflating: Dataset/Images/132/8.jpg
#   inflating: Dataset/Images/132/9.jpg
#    creating: Dataset/Images/133/
#   inflating: Dataset/Images/133/1.jpg
#   inflating: Dataset/Images/133/10.jpg
#   inflating: Dataset/Images/133/11.jpg
#   inflating: Dataset/Images/133/12.jpg
#   inflating: Dataset/Images/133/13.jpg
#   inflating: Dataset/Images/133/14.jpg
#   inflating: Dataset/Images/133/2.jpg
#   inflating: Dataset/Images/133/3.jpg
#   inflating: Dataset/Images/133/4.jpg
#   inflating: Dataset/Images/133/5.jpg
#   inflating: Dataset/Images/133/6.jpg
#   inflating: Dataset/Images/133/7.jpg
#   inflating: Dataset/Images/133/8.jpg
#   inflating: Dataset/Images/133/9.jpg
#    creating: Dataset/Images/134/
#   inflating: Dataset/Images/134/1.jpg
#   inflating: Dataset/Images/134/10.jpg
#   inflating: Dataset/Images/134/11.jpg
#   inflating: Dataset/Images/134/12.jpg
#   inflating: Dataset/Images/134/13.jpg
#   inflating: Dataset/Images/134/14.jpg
#   inflating: Dataset/Images/134/2.jpg
#   inflating: Dataset/Images/134/3.jpg
#   inflating: Dataset/Images/134/4.jpg
#   inflating: Dataset/Images/134/5.jpg
#   inflating: Dataset/Images/134/6.jpg
#   inflating: Dataset/Images/134/7.jpg
#   inflating: Dataset/Images/134/8.jpg
#   inflating: Dataset/Images/134/9.jpg
#    creating: Dataset/Images/135/
#   inflating: Dataset/Images/135/1.jpg
#   inflating: Dataset/Images/135/10.jpg
#   inflating: Dataset/Images/135/11.jpg
#   inflating: Dataset/Images/135/12.jpg
#   inflating: Dataset/Images/135/13.jpg
#   inflating: Dataset/Images/135/14.jpg
#   inflating: Dataset/Images/135/2.jpg
#   inflating: Dataset/Images/135/3.jpg
#   inflating: Dataset/Images/135/4.jpg
#   inflating: Dataset/Images/135/5.jpg
#   inflating: Dataset/Images/135/6.jpg
#   inflating: Dataset/Images/135/7.jpg
#   inflating: Dataset/Images/135/8.jpg
#   inflating: Dataset/Images/135/9.jpg
#    creating: Dataset/Images/136/
#   inflating: Dataset/Images/136/1.jpg
#   inflating: Dataset/Images/136/10.jpg
#   inflating: Dataset/Images/136/11.jpg
#   inflating: Dataset/Images/136/12.jpg
#   inflating: Dataset/Images/136/13.jpg
#   inflating: Dataset/Images/136/14.jpg
#   inflating: Dataset/Images/136/2.jpg
#   inflating: Dataset/Images/136/3.jpg
#   inflating: Dataset/Images/136/4.jpg
#   inflating: Dataset/Images/136/5.jpg
#   inflating: Dataset/Images/136/6.jpg
#   inflating: Dataset/Images/136/7.jpg
#   inflating: Dataset/Images/136/8.jpg
#   inflating: Dataset/Images/136/9.jpg
#    creating: Dataset/Images/137/
#   inflating: Dataset/Images/137/1.jpg
#   inflating: Dataset/Images/137/10.jpg
#   inflating: Dataset/Images/137/11.jpg
#   inflating: Dataset/Images/137/12.jpg
#   inflating: Dataset/Images/137/13.jpg
#   inflating: Dataset/Images/137/14.jpg
#   inflating: Dataset/Images/137/2.jpg
#   inflating: Dataset/Images/137/3.jpg
#   inflating: Dataset/Images/137/4.jpg
#   inflating: Dataset/Images/137/5.jpg
#   inflating: Dataset/Images/137/6.jpg
#   inflating: Dataset/Images/137/7.jpg
#   inflating: Dataset/Images/137/8.jpg
#   inflating: Dataset/Images/137/9.jpg
#    creating: Dataset/Images/138/
#   inflating: Dataset/Images/138/1.jpg
#   inflating: Dataset/Images/138/10.jpg
#   inflating: Dataset/Images/138/11.jpg
#   inflating: Dataset/Images/138/12.jpg
#   inflating: Dataset/Images/138/13.jpg
#   inflating: Dataset/Images/138/14.jpg
#   inflating: Dataset/Images/138/2.jpg
#   inflating: Dataset/Images/138/3.jpg
#   inflating: Dataset/Images/138/4.jpg
#   inflating: Dataset/Images/138/5.jpg
#   inflating: Dataset/Images/138/6.jpg
#   inflating: Dataset/Images/138/7.jpg
#   inflating: Dataset/Images/138/8.jpg
#   inflating: Dataset/Images/138/9.jpg
#    creating: Dataset/Images/139/
#   inflating: Dataset/Images/139/1.jpg
#   inflating: Dataset/Images/139/10.jpg
#   inflating: Dataset/Images/139/11.jpg
#   inflating: Dataset/Images/139/12.jpg
#   inflating: Dataset/Images/139/13.jpg
#   inflating: Dataset/Images/139/14.jpg
#   inflating: Dataset/Images/139/2.jpg
#   inflating: Dataset/Images/139/3.jpg
#   inflating: Dataset/Images/139/4.jpg
#   inflating: Dataset/Images/139/5.jpg
#   inflating: Dataset/Images/139/6.jpg
#   inflating: Dataset/Images/139/7.jpg
#   inflating: Dataset/Images/139/8.jpg
#   inflating: Dataset/Images/139/9.jpg
#    creating: Dataset/Images/14/
#   inflating: Dataset/Images/14/1.jpg
#   inflating: Dataset/Images/14/10.jpg
#   inflating: Dataset/Images/14/11.jpg
#   inflating: Dataset/Images/14/12.jpg
#   inflating: Dataset/Images/14/13.jpg
#   inflating: Dataset/Images/14/14.jpg
#   inflating: Dataset/Images/14/2.jpg
#   inflating: Dataset/Images/14/3.jpg
#   inflating: Dataset/Images/14/4.jpg
#   inflating: Dataset/Images/14/5.jpg
#   inflating: Dataset/Images/14/6.jpg
#   inflating: Dataset/Images/14/7.jpg
#   inflating: Dataset/Images/14/8.jpg
#   inflating: Dataset/Images/14/9.jpg
#    creating: Dataset/Images/140/
#   inflating: Dataset/Images/140/1.jpg
#   inflating: Dataset/Images/140/10.jpg
#   inflating: Dataset/Images/140/11.jpg
#   inflating: Dataset/Images/140/12.jpg
#   inflating: Dataset/Images/140/13.jpg
#   inflating: Dataset/Images/140/14.jpg
#   inflating: Dataset/Images/140/2.jpg
#   inflating: Dataset/Images/140/3.jpg
#   inflating: Dataset/Images/140/4.jpg
#   inflating: Dataset/Images/140/5.jpg
#   inflating: Dataset/Images/140/6.jpg
#   inflating: Dataset/Images/140/7.jpg
#   inflating: Dataset/Images/140/8.jpg
#   inflating: Dataset/Images/140/9.jpg
#    creating: Dataset/Images/141/
#   inflating: Dataset/Images/141/1.jpg
#   inflating: Dataset/Images/141/10.jpg
#   inflating: Dataset/Images/141/11.jpg
#   inflating: Dataset/Images/141/12.jpg
#   inflating: Dataset/Images/141/13.jpg
#   inflating: Dataset/Images/141/14.jpg
#   inflating: Dataset/Images/141/2.jpg
#   inflating: Dataset/Images/141/3.jpg
#   inflating: Dataset/Images/141/4.jpg
#   inflating: Dataset/Images/141/5.jpg
#   inflating: Dataset/Images/141/6.jpg
#   inflating: Dataset/Images/141/7.jpg
#   inflating: Dataset/Images/141/8.jpg
#   inflating: Dataset/Images/141/9.jpg
#    creating: Dataset/Images/142/
#   inflating: Dataset/Images/142/1.jpg
#   inflating: Dataset/Images/142/10.jpg
#   inflating: Dataset/Images/142/11.jpg
#   inflating: Dataset/Images/142/12.jpg
#   inflating: Dataset/Images/142/13.jpg
#   inflating: Dataset/Images/142/14.jpg
#   inflating: Dataset/Images/142/2.jpg
#   inflating: Dataset/Images/142/3.jpg
#   inflating: Dataset/Images/142/4.jpg
#   inflating: Dataset/Images/142/5.jpg
#   inflating: Dataset/Images/142/6.jpg
#   inflating: Dataset/Images/142/7.jpg
#   inflating: Dataset/Images/142/8.jpg
#   inflating: Dataset/Images/142/9.jpg
#    creating: Dataset/Images/143/
#   inflating: Dataset/Images/143/1.jpg
#   inflating: Dataset/Images/143/10.jpg
#   inflating: Dataset/Images/143/11.jpg
#   inflating: Dataset/Images/143/12.jpg
#   inflating: Dataset/Images/143/13.jpg
#   inflating: Dataset/Images/143/14.jpg
#   inflating: Dataset/Images/143/2.jpg
#   inflating: Dataset/Images/143/3.jpg
#   inflating: Dataset/Images/143/4.jpg
#   inflating: Dataset/Images/143/5.jpg
#   inflating: Dataset/Images/143/6.jpg
#   inflating: Dataset/Images/143/7.jpg
#   inflating: Dataset/Images/143/8.jpg
#   inflating: Dataset/Images/143/9.jpg
#    creating: Dataset/Images/144/
#   inflating: Dataset/Images/144/1.jpg
#   inflating: Dataset/Images/144/10.jpg
#   inflating: Dataset/Images/144/11.jpg
#   inflating: Dataset/Images/144/12.jpg
#   inflating: Dataset/Images/144/13.jpg
#   inflating: Dataset/Images/144/14.jpg
#   inflating: Dataset/Images/144/2.jpg
#   inflating: Dataset/Images/144/3.jpg
#   inflating: Dataset/Images/144/4.jpg
#   inflating: Dataset/Images/144/5.jpg
#   inflating: Dataset/Images/144/6.jpg
#   inflating: Dataset/Images/144/7.jpg
#   inflating: Dataset/Images/144/8.jpg
#   inflating: Dataset/Images/144/9.jpg
#    creating: Dataset/Images/145/
#   inflating: Dataset/Images/145/1.jpg
#   inflating: Dataset/Images/145/10.jpg
#   inflating: Dataset/Images/145/11.jpg
#   inflating: Dataset/Images/145/12.jpg
#   inflating: Dataset/Images/145/13.jpg
#   inflating: Dataset/Images/145/14.jpg
#   inflating: Dataset/Images/145/2.jpg
#   inflating: Dataset/Images/145/3.jpg
#   inflating: Dataset/Images/145/4.jpg
#   inflating: Dataset/Images/145/5.jpg
#   inflating: Dataset/Images/145/6.jpg
#   inflating: Dataset/Images/145/7.jpg
#   inflating: Dataset/Images/145/8.jpg
#   inflating: Dataset/Images/145/9.jpg
#    creating: Dataset/Images/146/
#   inflating: Dataset/Images/146/1.jpg
#   inflating: Dataset/Images/146/10.jpg
#   inflating: Dataset/Images/146/11.jpg
#   inflating: Dataset/Images/146/12.jpg
#   inflating: Dataset/Images/146/13.jpg
#   inflating: Dataset/Images/146/14.jpg
#   inflating: Dataset/Images/146/2.jpg
#   inflating: Dataset/Images/146/3.jpg
#   inflating: Dataset/Images/146/4.jpg
#   inflating: Dataset/Images/146/5.jpg
#   inflating: Dataset/Images/146/6.jpg
#   inflating: Dataset/Images/146/7.jpg
#   inflating: Dataset/Images/146/8.jpg
#   inflating: Dataset/Images/146/9.jpg
#    creating: Dataset/Images/147/
#   inflating: Dataset/Images/147/1.jpg
#   inflating: Dataset/Images/147/10.jpg
#   inflating: Dataset/Images/147/11.jpg
#   inflating: Dataset/Images/147/12.jpg
#   inflating: Dataset/Images/147/13.jpg
#   inflating: Dataset/Images/147/14.jpg
#   inflating: Dataset/Images/147/2.jpg
#   inflating: Dataset/Images/147/3.jpg
#   inflating: Dataset/Images/147/4.jpg
#   inflating: Dataset/Images/147/5.jpg
#   inflating: Dataset/Images/147/6.jpg
#   inflating: Dataset/Images/147/7.jpg
#   inflating: Dataset/Images/147/8.jpg
#   inflating: Dataset/Images/147/9.jpg
#    creating: Dataset/Images/148/
#   inflating: Dataset/Images/148/1.jpg
#   inflating: Dataset/Images/148/10.jpg
#   inflating: Dataset/Images/148/11.jpg
#   inflating: Dataset/Images/148/12.jpg
#   inflating: Dataset/Images/148/13.jpg
#   inflating: Dataset/Images/148/14.jpg
#   inflating: Dataset/Images/148/2.jpg
#   inflating: Dataset/Images/148/3.jpg
#   inflating: Dataset/Images/148/4.jpg
#   inflating: Dataset/Images/148/5.jpg
#   inflating: Dataset/Images/148/6.jpg
#   inflating: Dataset/Images/148/7.jpg
#   inflating: Dataset/Images/148/8.jpg
#   inflating: Dataset/Images/148/9.jpg
#    creating: Dataset/Images/149/
#   inflating: Dataset/Images/149/1.jpg
#   inflating: Dataset/Images/149/10.jpg
#   inflating: Dataset/Images/149/11.jpg
#   inflating: Dataset/Images/149/12.jpg
#   inflating: Dataset/Images/149/13.jpg
#   inflating: Dataset/Images/149/14.jpg
#   inflating: Dataset/Images/149/2.jpg
#   inflating: Dataset/Images/149/3.jpg
#   inflating: Dataset/Images/149/4.jpg
#   inflating: Dataset/Images/149/5.jpg
#   inflating: Dataset/Images/149/6.jpg
#   inflating: Dataset/Images/149/7.jpg
#   inflating: Dataset/Images/149/8.jpg
#   inflating: Dataset/Images/149/9.jpg
#    creating: Dataset/Images/15/
#   inflating: Dataset/Images/15/1.jpg
#   inflating: Dataset/Images/15/10.jpg
#   inflating: Dataset/Images/15/11.jpg
#   inflating: Dataset/Images/15/12.jpg
#   inflating: Dataset/Images/15/13.jpg
#   inflating: Dataset/Images/15/14.jpg
#   inflating: Dataset/Images/15/2.jpg
#   inflating: Dataset/Images/15/3.jpg
#   inflating: Dataset/Images/15/4.jpg
#   inflating: Dataset/Images/15/5.jpg
#   inflating: Dataset/Images/15/6.jpg
#   inflating: Dataset/Images/15/7.jpg
#   inflating: Dataset/Images/15/8.jpg
#   inflating: Dataset/Images/15/9.jpg
#    creating: Dataset/Images/150/
#   inflating: Dataset/Images/150/1.jpg
#   inflating: Dataset/Images/150/10.jpg
#   inflating: Dataset/Images/150/11.jpg
#   inflating: Dataset/Images/150/12.jpg
#   inflating: Dataset/Images/150/13.jpg
#   inflating: Dataset/Images/150/14.jpg
#   inflating: Dataset/Images/150/2.jpg
#   inflating: Dataset/Images/150/3.jpg
#   inflating: Dataset/Images/150/4.jpg
#   inflating: Dataset/Images/150/5.jpg
#   inflating: Dataset/Images/150/6.jpg
#   inflating: Dataset/Images/150/7.jpg
#   inflating: Dataset/Images/150/8.jpg
#   inflating: Dataset/Images/150/9.jpg
#    creating: Dataset/Images/151/
#   inflating: Dataset/Images/151/1.jpg
#   inflating: Dataset/Images/151/10.jpg
#   inflating: Dataset/Images/151/11.jpg
#   inflating: Dataset/Images/151/12.jpg
#   inflating: Dataset/Images/151/13.jpg
#   inflating: Dataset/Images/151/14.jpg
#   inflating: Dataset/Images/151/2.jpg
#   inflating: Dataset/Images/151/3.jpg
#   inflating: Dataset/Images/151/4.jpg
#   inflating: Dataset/Images/151/5.jpg
#   inflating: Dataset/Images/151/6.jpg
#   inflating: Dataset/Images/151/7.jpg
#   inflating: Dataset/Images/151/8.jpg
#   inflating: Dataset/Images/151/9.jpg
#    creating: Dataset/Images/152/
#   inflating: Dataset/Images/152/1.jpg
#   inflating: Dataset/Images/152/10.jpg
#   inflating: Dataset/Images/152/11.jpg
#   inflating: Dataset/Images/152/12.jpg
#   inflating: Dataset/Images/152/13.jpg
#   inflating: Dataset/Images/152/14.jpg
#   inflating: Dataset/Images/152/2.jpg
#   inflating: Dataset/Images/152/3.jpg
#   inflating: Dataset/Images/152/4.jpg
#   inflating: Dataset/Images/152/5.jpg
#   inflating: Dataset/Images/152/6.jpg
#   inflating: Dataset/Images/152/7.jpg
#   inflating: Dataset/Images/152/8.jpg
#   inflating: Dataset/Images/152/9.jpg
#    creating: Dataset/Images/153/
#   inflating: Dataset/Images/153/1.jpg
#   inflating: Dataset/Images/153/10.jpg
#   inflating: Dataset/Images/153/11.jpg
#   inflating: Dataset/Images/153/12.jpg
#   inflating: Dataset/Images/153/13.jpg
#   inflating: Dataset/Images/153/14.jpg
#   inflating: Dataset/Images/153/2.jpg
#   inflating: Dataset/Images/153/3.jpg
#   inflating: Dataset/Images/153/4.jpg
#   inflating: Dataset/Images/153/5.jpg
#   inflating: Dataset/Images/153/6.jpg
#   inflating: Dataset/Images/153/7.jpg
#   inflating: Dataset/Images/153/8.jpg
#   inflating: Dataset/Images/153/9.jpg
#    creating: Dataset/Images/154/
#   inflating: Dataset/Images/154/1.jpg
#   inflating: Dataset/Images/154/10.jpg
#   inflating: Dataset/Images/154/11.jpg
#   inflating: Dataset/Images/154/12.jpg
#   inflating: Dataset/Images/154/13.jpg
#   inflating: Dataset/Images/154/14.jpg
#   inflating: Dataset/Images/154/2.jpg
#   inflating: Dataset/Images/154/3.jpg
#   inflating: Dataset/Images/154/4.jpg
#   inflating: Dataset/Images/154/5.jpg
#   inflating: Dataset/Images/154/6.jpg
#   inflating: Dataset/Images/154/7.jpg
#   inflating: Dataset/Images/154/8.jpg
#   inflating: Dataset/Images/154/9.jpg
#    creating: Dataset/Images/155/
#   inflating: Dataset/Images/155/1.jpg
#   inflating: Dataset/Images/155/10.jpg
#   inflating: Dataset/Images/155/11.jpg
#   inflating: Dataset/Images/155/12.jpg
#   inflating: Dataset/Images/155/13.jpg
#   inflating: Dataset/Images/155/14.jpg
#   inflating: Dataset/Images/155/2.jpg
#   inflating: Dataset/Images/155/3.jpg
#   inflating: Dataset/Images/155/4.jpg
#   inflating: Dataset/Images/155/5.jpg
#   inflating: Dataset/Images/155/6.jpg
#   inflating: Dataset/Images/155/7.jpg
#   inflating: Dataset/Images/155/8.jpg
#   inflating: Dataset/Images/155/9.jpg
#    creating: Dataset/Images/156/
#   inflating: Dataset/Images/156/1.jpg
#   inflating: Dataset/Images/156/10.jpg
#   inflating: Dataset/Images/156/11.jpg
#   inflating: Dataset/Images/156/12.jpg
#   inflating: Dataset/Images/156/13.jpg
#   inflating: Dataset/Images/156/14.jpg
#   inflating: Dataset/Images/156/2.jpg
#   inflating: Dataset/Images/156/3.jpg
#   inflating: Dataset/Images/156/4.jpg
#   inflating: Dataset/Images/156/5.jpg
#   inflating: Dataset/Images/156/6.jpg
#   inflating: Dataset/Images/156/7.jpg
#   inflating: Dataset/Images/156/8.jpg
#   inflating: Dataset/Images/156/9.jpg
#    creating: Dataset/Images/157/
#   inflating: Dataset/Images/157/1.jpg
#   inflating: Dataset/Images/157/10.jpg
#   inflating: Dataset/Images/157/11.jpg
#   inflating: Dataset/Images/157/12.jpg
#   inflating: Dataset/Images/157/13.jpg
#   inflating: Dataset/Images/157/14.jpg
#   inflating: Dataset/Images/157/2.jpg
#   inflating: Dataset/Images/157/3.jpg
#   inflating: Dataset/Images/157/4.jpg
#   inflating: Dataset/Images/157/5.jpg
#   inflating: Dataset/Images/157/6.jpg
#   inflating: Dataset/Images/157/7.jpg
#   inflating: Dataset/Images/157/8.jpg
#   inflating: Dataset/Images/157/9.jpg
#    creating: Dataset/Images/158/
#   inflating: Dataset/Images/158/1.jpg
#   inflating: Dataset/Images/158/10.jpg
#   inflating: Dataset/Images/158/11.jpg
#   inflating: Dataset/Images/158/12.jpg
#   inflating: Dataset/Images/158/13.jpg
#   inflating: Dataset/Images/158/14.jpg
#   inflating: Dataset/Images/158/2.jpg
#   inflating: Dataset/Images/158/3.jpg
#   inflating: Dataset/Images/158/4.jpg
#   inflating: Dataset/Images/158/5.jpg
#   inflating: Dataset/Images/158/6.jpg
#   inflating: Dataset/Images/158/7.jpg
#   inflating: Dataset/Images/158/8.jpg
#   inflating: Dataset/Images/158/9.jpg
#    creating: Dataset/Images/159/
#   inflating: Dataset/Images/159/1.jpg
#   inflating: Dataset/Images/159/10.jpg
#   inflating: Dataset/Images/159/11.jpg
#   inflating: Dataset/Images/159/12.jpg
#   inflating: Dataset/Images/159/13.jpg
#   inflating: Dataset/Images/159/14.jpg
#   inflating: Dataset/Images/159/2.jpg
#   inflating: Dataset/Images/159/3.jpg
#   inflating: Dataset/Images/159/4.jpg
#   inflating: Dataset/Images/159/5.jpg
#   inflating: Dataset/Images/159/6.jpg
#   inflating: Dataset/Images/159/7.jpg
#   inflating: Dataset/Images/159/8.jpg
#   inflating: Dataset/Images/159/9.jpg
#    creating: Dataset/Images/16/
#   inflating: Dataset/Images/16/1.jpg
#   inflating: Dataset/Images/16/10.jpg
#   inflating: Dataset/Images/16/11.jpg
#   inflating: Dataset/Images/16/12.jpg
#   inflating: Dataset/Images/16/13.jpg
#   inflating: Dataset/Images/16/14.jpg
#   inflating: Dataset/Images/16/2.jpg
#   inflating: Dataset/Images/16/3.jpg
#   inflating: Dataset/Images/16/4.jpg
#   inflating: Dataset/Images/16/5.jpg
#   inflating: Dataset/Images/16/6.jpg
#   inflating: Dataset/Images/16/7.jpg
#   inflating: Dataset/Images/16/8.jpg
#   inflating: Dataset/Images/16/9.jpg
#    creating: Dataset/Images/160/
#   inflating: Dataset/Images/160/1.jpg
#   inflating: Dataset/Images/160/10.jpg
#   inflating: Dataset/Images/160/11.jpg
#   inflating: Dataset/Images/160/12.jpg
#   inflating: Dataset/Images/160/13.jpg
#   inflating: Dataset/Images/160/14.jpg
#   inflating: Dataset/Images/160/2.jpg
#   inflating: Dataset/Images/160/3.jpg
#   inflating: Dataset/Images/160/4.jpg
#   inflating: Dataset/Images/160/5.jpg
#   inflating: Dataset/Images/160/6.jpg
#   inflating: Dataset/Images/160/7.jpg
#   inflating: Dataset/Images/160/8.jpg
#   inflating: Dataset/Images/160/9.jpg
#    creating: Dataset/Images/161/
#   inflating: Dataset/Images/161/1.jpg
#   inflating: Dataset/Images/161/10.jpg
#   inflating: Dataset/Images/161/11.jpg
#   inflating: Dataset/Images/161/12.jpg
#   inflating: Dataset/Images/161/13.jpg
#   inflating: Dataset/Images/161/14.jpg
#   inflating: Dataset/Images/161/2.jpg
#   inflating: Dataset/Images/161/3.jpg
#   inflating: Dataset/Images/161/4.jpg
#   inflating: Dataset/Images/161/5.jpg
#   inflating: Dataset/Images/161/6.jpg
#   inflating: Dataset/Images/161/7.jpg
#   inflating: Dataset/Images/161/8.jpg
#   inflating: Dataset/Images/161/9.jpg
#    creating: Dataset/Images/162/
#   inflating: Dataset/Images/162/1.jpg
#   inflating: Dataset/Images/162/10.jpg
#   inflating: Dataset/Images/162/11.jpg
#   inflating: Dataset/Images/162/12.jpg
#   inflating: Dataset/Images/162/13.jpg
#   inflating: Dataset/Images/162/14.jpg
#   inflating: Dataset/Images/162/2.jpg
#   inflating: Dataset/Images/162/3.jpg
#   inflating: Dataset/Images/162/4.jpg
#   inflating: Dataset/Images/162/5.jpg
#   inflating: Dataset/Images/162/6.jpg
#   inflating: Dataset/Images/162/7.jpg
#   inflating: Dataset/Images/162/8.jpg
#   inflating: Dataset/Images/162/9.jpg
#    creating: Dataset/Images/163/
#   inflating: Dataset/Images/163/1.jpg
#   inflating: Dataset/Images/163/10.jpg
#   inflating: Dataset/Images/163/11.jpg
#   inflating: Dataset/Images/163/12.jpg
#   inflating: Dataset/Images/163/13.jpg
#   inflating: Dataset/Images/163/14.jpg
#   inflating: Dataset/Images/163/2.jpg
#   inflating: Dataset/Images/163/3.jpg
#   inflating: Dataset/Images/163/4.jpg
#   inflating: Dataset/Images/163/5.jpg
#   inflating: Dataset/Images/163/6.jpg
#   inflating: Dataset/Images/163/7.jpg
#   inflating: Dataset/Images/163/8.jpg
#   inflating: Dataset/Images/163/9.jpg
#    creating: Dataset/Images/164/
#   inflating: Dataset/Images/164/1.jpg
#   inflating: Dataset/Images/164/10.jpg
#   inflating: Dataset/Images/164/11.jpg
#   inflating: Dataset/Images/164/12.jpg
#   inflating: Dataset/Images/164/13.jpg
#   inflating: Dataset/Images/164/14.jpg
#   inflating: Dataset/Images/164/2.jpg
#   inflating: Dataset/Images/164/3.jpg
#   inflating: Dataset/Images/164/4.jpg
#   inflating: Dataset/Images/164/5.jpg
#   inflating: Dataset/Images/164/6.jpg
#   inflating: Dataset/Images/164/7.jpg
#   inflating: Dataset/Images/164/8.jpg
#   inflating: Dataset/Images/164/9.jpg
#    creating: Dataset/Images/165/
#   inflating: Dataset/Images/165/1.jpg
#   inflating: Dataset/Images/165/10.jpg
#   inflating: Dataset/Images/165/11.jpg
#   inflating: Dataset/Images/165/12.jpg
#   inflating: Dataset/Images/165/13.jpg
#   inflating: Dataset/Images/165/14.jpg
#   inflating: Dataset/Images/165/2.jpg
#   inflating: Dataset/Images/165/3.jpg
#   inflating: Dataset/Images/165/4.jpg
#   inflating: Dataset/Images/165/5.jpg
#   inflating: Dataset/Images/165/6.jpg
#   inflating: Dataset/Images/165/7.jpg
#   inflating: Dataset/Images/165/8.jpg
#   inflating: Dataset/Images/165/9.jpg
#    creating: Dataset/Images/166/
#   inflating: Dataset/Images/166/1.jpg
#   inflating: Dataset/Images/166/10.jpg
#   inflating: Dataset/Images/166/11.jpg
#   inflating: Dataset/Images/166/12.jpg
#   inflating: Dataset/Images/166/13.jpg
#   inflating: Dataset/Images/166/14.jpg
#   inflating: Dataset/Images/166/2.jpg
#   inflating: Dataset/Images/166/3.jpg
#   inflating: Dataset/Images/166/4.jpg
#   inflating: Dataset/Images/166/5.jpg
#   inflating: Dataset/Images/166/6.jpg
#   inflating: Dataset/Images/166/7.jpg
#   inflating: Dataset/Images/166/8.jpg
#   inflating: Dataset/Images/166/9.jpg
#    creating: Dataset/Images/167/
#   inflating: Dataset/Images/167/1.jpg
#   inflating: Dataset/Images/167/10.jpg
#   inflating: Dataset/Images/167/11.jpg
#   inflating: Dataset/Images/167/12.jpg
#   inflating: Dataset/Images/167/13.jpg
#   inflating: Dataset/Images/167/14.jpg
#   inflating: Dataset/Images/167/2.jpg
#   inflating: Dataset/Images/167/3.jpg
#   inflating: Dataset/Images/167/4.jpg
#   inflating: Dataset/Images/167/5.jpg
#   inflating: Dataset/Images/167/6.jpg
#   inflating: Dataset/Images/167/7.jpg
#   inflating: Dataset/Images/167/8.jpg
#   inflating: Dataset/Images/167/9.jpg
#    creating: Dataset/Images/168/
#   inflating: Dataset/Images/168/1.jpg
#   inflating: Dataset/Images/168/10.jpg
# ...
#   inflating: Dataset/Images/76/1.jpg
#   inflating: Dataset/Images/76/10.jpg
#   inflating: Dataset/Images/76/11.jpg
#   inflating: Dataset/Images/76/12.jpg
#   inflating: Dataset/Images/76/13.jpg
#   inflating: Dataset/Images/76/14.jpg
#   inflating: Dataset/Images/76/2.jpg
#   inflating: Dataset/Images/76/3.jpg
#   inflating: Dataset/Images/76/4.jpg
#   inflating: Dataset/Images/76/5.jpg
#   inflating: Dataset/Images/76/6.jpg
#   inflating: Dataset/Images/76/7.jpg
#   inflating: Dataset/Images/76/8.jpg
#   inflating: Dataset/Images/76/9.jpg
#    creating: Dataset/Images/77/
#   inflating: Dataset/Images/77/1.jpg
#   inflating: Dataset/Images/77/10.jpg
#   inflating: Dataset/Images/77/11.jpg
#   inflating: Dataset/Images/77/12.jpg
#   inflating: Dataset/Images/77/13.jpg
#   inflating: Dataset/Images/77/14.jpg
#   inflating: Dataset/Images/77/2.jpg
#   inflating: Dataset/Images/77/3.jpg
#   inflating: Dataset/Images/77/4.jpg
#   inflating: Dataset/Images/77/5.jpg
#   inflating: Dataset/Images/77/6.jpg
#   inflating: Dataset/Images/77/7.jpg
#   inflating: Dataset/Images/77/8.jpg
#   inflating: Dataset/Images/77/9.jpg
#    creating: Dataset/Images/78/
#   inflating: Dataset/Images/78/1.jpg
#   inflating: Dataset/Images/78/10.jpg
#   inflating: Dataset/Images/78/11.jpg
#   inflating: Dataset/Images/78/12.jpg
#   inflating: Dataset/Images/78/13.jpg
#   inflating: Dataset/Images/78/14.jpg
#   inflating: Dataset/Images/78/2.jpg
#   inflating: Dataset/Images/78/3.jpg
#   inflating: Dataset/Images/78/4.jpg
#   inflating: Dataset/Images/78/5.jpg
#   inflating: Dataset/Images/78/6.jpg
#   inflating: Dataset/Images/78/7.jpg
#   inflating: Dataset/Images/78/8.jpg
#   inflating: Dataset/Images/78/9.jpg
#    creating: Dataset/Images/79/
#   inflating: Dataset/Images/79/1.jpg
#   inflating: Dataset/Images/79/10.jpg
#   inflating: Dataset/Images/79/11.jpg
#   inflating: Dataset/Images/79/12.jpg
#   inflating: Dataset/Images/79/13.jpg
#   inflating: Dataset/Images/79/14.jpg
#   inflating: Dataset/Images/79/2.jpg
#   inflating: Dataset/Images/79/3.jpg
#   inflating: Dataset/Images/79/4.jpg
#   inflating: Dataset/Images/79/5.jpg
#   inflating: Dataset/Images/79/6.jpg
#   inflating: Dataset/Images/79/7.jpg
#   inflating: Dataset/Images/79/8.jpg
#   inflating: Dataset/Images/79/9.jpg
#    creating: Dataset/Images/8/
#   inflating: Dataset/Images/8/1.jpg
#   inflating: Dataset/Images/8/10.jpg
#   inflating: Dataset/Images/8/11.jpg
#   inflating: Dataset/Images/8/12.jpg
#   inflating: Dataset/Images/8/13.jpg
#   inflating: Dataset/Images/8/14.jpg
#   inflating: Dataset/Images/8/2.jpg
#   inflating: Dataset/Images/8/3.jpg
#   inflating: Dataset/Images/8/4.jpg
#   inflating: Dataset/Images/8/5.jpg
#   inflating: Dataset/Images/8/6.jpg
#   inflating: Dataset/Images/8/7.jpg
#   inflating: Dataset/Images/8/8.jpg
#   inflating: Dataset/Images/8/9.jpg
#    creating: Dataset/Images/80/
#   inflating: Dataset/Images/80/1.jpg
#   inflating: Dataset/Images/80/10.jpg
#   inflating: Dataset/Images/80/11.jpg
#   inflating: Dataset/Images/80/12.jpg
#   inflating: Dataset/Images/80/13.jpg
#   inflating: Dataset/Images/80/14.jpg
#   inflating: Dataset/Images/80/2.jpg
#   inflating: Dataset/Images/80/3.jpg
#   inflating: Dataset/Images/80/4.jpg
#   inflating: Dataset/Images/80/5.jpg
#   inflating: Dataset/Images/80/6.jpg
#   inflating: Dataset/Images/80/7.jpg
#   inflating: Dataset/Images/80/8.jpg
#   inflating: Dataset/Images/80/9.jpg
#    creating: Dataset/Images/81/
#   inflating: Dataset/Images/81/1.jpg
#   inflating: Dataset/Images/81/10.jpg
#   inflating: Dataset/Images/81/11.jpg
#   inflating: Dataset/Images/81/12.jpg
#   inflating: Dataset/Images/81/13.jpg
#   inflating: Dataset/Images/81/14.jpg
#   inflating: Dataset/Images/81/2.jpg
#   inflating: Dataset/Images/81/3.jpg
#   inflating: Dataset/Images/81/4.jpg
#   inflating: Dataset/Images/81/5.jpg
#   inflating: Dataset/Images/81/6.jpg
#   inflating: Dataset/Images/81/7.jpg
#   inflating: Dataset/Images/81/8.jpg
#   inflating: Dataset/Images/81/9.jpg
#    creating: Dataset/Images/82/
#   inflating: Dataset/Images/82/1.jpg
#   inflating: Dataset/Images/82/10.jpg
#   inflating: Dataset/Images/82/11.jpg
#   inflating: Dataset/Images/82/12.jpg
#   inflating: Dataset/Images/82/13.jpg
#   inflating: Dataset/Images/82/14.jpg
#   inflating: Dataset/Images/82/2.jpg
#   inflating: Dataset/Images/82/3.jpg
#   inflating: Dataset/Images/82/4.jpg
#   inflating: Dataset/Images/82/5.jpg
#   inflating: Dataset/Images/82/6.jpg
#   inflating: Dataset/Images/82/7.jpg
#   inflating: Dataset/Images/82/8.jpg
#   inflating: Dataset/Images/82/9.jpg
#    creating: Dataset/Images/83/
#   inflating: Dataset/Images/83/1.jpg
#   inflating: Dataset/Images/83/10.jpg
#   inflating: Dataset/Images/83/11.jpg
#   inflating: Dataset/Images/83/12.jpg
#   inflating: Dataset/Images/83/13.jpg
#   inflating: Dataset/Images/83/14.jpg
#   inflating: Dataset/Images/83/2.jpg
#   inflating: Dataset/Images/83/3.jpg
#   inflating: Dataset/Images/83/4.jpg
#   inflating: Dataset/Images/83/5.jpg
#   inflating: Dataset/Images/83/6.jpg
#   inflating: Dataset/Images/83/7.jpg
#   inflating: Dataset/Images/83/8.jpg
#   inflating: Dataset/Images/83/9.jpg
#    creating: Dataset/Images/84/
#   inflating: Dataset/Images/84/1.jpg
#   inflating: Dataset/Images/84/10.jpg
#   inflating: Dataset/Images/84/11.jpg
#   inflating: Dataset/Images/84/12.jpg
#   inflating: Dataset/Images/84/13.jpg
#   inflating: Dataset/Images/84/14.jpg
#   inflating: Dataset/Images/84/2.jpg
#   inflating: Dataset/Images/84/3.jpg
#   inflating: Dataset/Images/84/4.jpg
#   inflating: Dataset/Images/84/5.jpg
#   inflating: Dataset/Images/84/6.jpg
#   inflating: Dataset/Images/84/7.jpg
#   inflating: Dataset/Images/84/8.jpg
#   inflating: Dataset/Images/84/9.jpg
#    creating: Dataset/Images/85/
#   inflating: Dataset/Images/85/1.jpg
#   inflating: Dataset/Images/85/10.jpg
#   inflating: Dataset/Images/85/11.jpg
#   inflating: Dataset/Images/85/12.jpg
#   inflating: Dataset/Images/85/13.jpg
#   inflating: Dataset/Images/85/14.jpg
#   inflating: Dataset/Images/85/2.jpg
#   inflating: Dataset/Images/85/3.jpg
#   inflating: Dataset/Images/85/4.jpg
#   inflating: Dataset/Images/85/5.jpg
#   inflating: Dataset/Images/85/6.jpg
#   inflating: Dataset/Images/85/7.jpg
#   inflating: Dataset/Images/85/8.jpg
#   inflating: Dataset/Images/85/9.jpg
#    creating: Dataset/Images/86/
#   inflating: Dataset/Images/86/1.jpg
#   inflating: Dataset/Images/86/10.jpg
#   inflating: Dataset/Images/86/11.jpg
#   inflating: Dataset/Images/86/12.jpg
#   inflating: Dataset/Images/86/13.jpg
#   inflating: Dataset/Images/86/14.jpg
#   inflating: Dataset/Images/86/2.jpg
#   inflating: Dataset/Images/86/3.jpg
#   inflating: Dataset/Images/86/4.jpg
#   inflating: Dataset/Images/86/5.jpg
#   inflating: Dataset/Images/86/6.jpg
#   inflating: Dataset/Images/86/7.jpg
#   inflating: Dataset/Images/86/8.jpg
#   inflating: Dataset/Images/86/9.jpg
#    creating: Dataset/Images/87/
#   inflating: Dataset/Images/87/1.jpg
#   inflating: Dataset/Images/87/10.jpg
#   inflating: Dataset/Images/87/11.jpg
#   inflating: Dataset/Images/87/12.jpg
#   inflating: Dataset/Images/87/13.jpg
#   inflating: Dataset/Images/87/14.jpg
#   inflating: Dataset/Images/87/2.jpg
#   inflating: Dataset/Images/87/3.jpg
#   inflating: Dataset/Images/87/4.jpg
#   inflating: Dataset/Images/87/5.jpg
#   inflating: Dataset/Images/87/6.jpg
#   inflating: Dataset/Images/87/7.jpg
#   inflating: Dataset/Images/87/8.jpg
#   inflating: Dataset/Images/87/9.jpg
#    creating: Dataset/Images/88/
#   inflating: Dataset/Images/88/1.jpg
#   inflating: Dataset/Images/88/10.jpg
#   inflating: Dataset/Images/88/11.jpg
#   inflating: Dataset/Images/88/12.jpg
#   inflating: Dataset/Images/88/13.jpg
#   inflating: Dataset/Images/88/14.jpg
#   inflating: Dataset/Images/88/2.jpg
#   inflating: Dataset/Images/88/3.jpg
#   inflating: Dataset/Images/88/4.jpg
#   inflating: Dataset/Images/88/5.jpg
#   inflating: Dataset/Images/88/6.jpg
#   inflating: Dataset/Images/88/7.jpg
#   inflating: Dataset/Images/88/8.jpg
#   inflating: Dataset/Images/88/9.jpg
#    creating: Dataset/Images/89/
#   inflating: Dataset/Images/89/1.jpg
#   inflating: Dataset/Images/89/10.jpg
#   inflating: Dataset/Images/89/11.jpg
#   inflating: Dataset/Images/89/12.jpg
#   inflating: Dataset/Images/89/13.jpg
#   inflating: Dataset/Images/89/14.jpg
#   inflating: Dataset/Images/89/2.jpg
#   inflating: Dataset/Images/89/3.jpg
#   inflating: Dataset/Images/89/4.jpg
#   inflating: Dataset/Images/89/5.jpg
#   inflating: Dataset/Images/89/6.jpg
#   inflating: Dataset/Images/89/7.jpg
#   inflating: Dataset/Images/89/8.jpg
#   inflating: Dataset/Images/89/9.jpg
#    creating: Dataset/Images/9/
#   inflating: Dataset/Images/9/1.jpg
#   inflating: Dataset/Images/9/10.jpg
#   inflating: Dataset/Images/9/11.jpg
#   inflating: Dataset/Images/9/12.jpg
#   inflating: Dataset/Images/9/13.jpg
#   inflating: Dataset/Images/9/14.jpg
#   inflating: Dataset/Images/9/2.jpg
#   inflating: Dataset/Images/9/3.jpg
#   inflating: Dataset/Images/9/4.jpg
#   inflating: Dataset/Images/9/5.jpg
#   inflating: Dataset/Images/9/6.jpg
#   inflating: Dataset/Images/9/7.jpg
#   inflating: Dataset/Images/9/8.jpg
#   inflating: Dataset/Images/9/9.jpg
#    creating: Dataset/Images/90/
#   inflating: Dataset/Images/90/1.jpg
#   inflating: Dataset/Images/90/10.jpg
#   inflating: Dataset/Images/90/11.jpg
#   inflating: Dataset/Images/90/12.jpg
#   inflating: Dataset/Images/90/13.jpg
#   inflating: Dataset/Images/90/14.jpg
#   inflating: Dataset/Images/90/2.jpg
#   inflating: Dataset/Images/90/3.jpg
#   inflating: Dataset/Images/90/4.jpg
#   inflating: Dataset/Images/90/5.jpg
#   inflating: Dataset/Images/90/6.jpg
#   inflating: Dataset/Images/90/7.jpg
#   inflating: Dataset/Images/90/8.jpg
#   inflating: Dataset/Images/90/9.jpg
#    creating: Dataset/Images/91/
#   inflating: Dataset/Images/91/1.jpg
#   inflating: Dataset/Images/91/10.jpg
#   inflating: Dataset/Images/91/11.jpg
#   inflating: Dataset/Images/91/12.jpg
#   inflating: Dataset/Images/91/13.jpg
#   inflating: Dataset/Images/91/14.jpg
#   inflating: Dataset/Images/91/2.jpg
#   inflating: Dataset/Images/91/3.jpg
#   inflating: Dataset/Images/91/4.jpg
#   inflating: Dataset/Images/91/5.jpg
#   inflating: Dataset/Images/91/6.jpg
#   inflating: Dataset/Images/91/7.jpg
#   inflating: Dataset/Images/91/8.jpg
#   inflating: Dataset/Images/91/9.jpg
#    creating: Dataset/Images/92/
#   inflating: Dataset/Images/92/1.jpg
#   inflating: Dataset/Images/92/10.jpg
#   inflating: Dataset/Images/92/11.jpg
#   inflating: Dataset/Images/92/12.jpg
#   inflating: Dataset/Images/92/13.jpg
#   inflating: Dataset/Images/92/14.jpg
#   inflating: Dataset/Images/92/2.jpg
#   inflating: Dataset/Images/92/3.jpg
#   inflating: Dataset/Images/92/4.jpg
#   inflating: Dataset/Images/92/5.jpg
#   inflating: Dataset/Images/92/6.jpg
#   inflating: Dataset/Images/92/7.jpg
#   inflating: Dataset/Images/92/8.jpg
#   inflating: Dataset/Images/92/9.jpg
#    creating: Dataset/Images/93/
#   inflating: Dataset/Images/93/1.jpg
#   inflating: Dataset/Images/93/10.jpg
#   inflating: Dataset/Images/93/11.jpg
#   inflating: Dataset/Images/93/12.jpg
#   inflating: Dataset/Images/93/13.jpg
#   inflating: Dataset/Images/93/14.jpg
#   inflating: Dataset/Images/93/2.jpg
#   inflating: Dataset/Images/93/3.jpg
#   inflating: Dataset/Images/93/4.jpg
#   inflating: Dataset/Images/93/5.jpg
#   inflating: Dataset/Images/93/6.jpg
#   inflating: Dataset/Images/93/7.jpg
#   inflating: Dataset/Images/93/8.jpg
#   inflating: Dataset/Images/93/9.jpg
#    creating: Dataset/Images/94/
#   inflating: Dataset/Images/94/1.jpg
#   inflating: Dataset/Images/94/10.jpg
#   inflating: Dataset/Images/94/11.jpg
#   inflating: Dataset/Images/94/12.jpg
#   inflating: Dataset/Images/94/13.jpg
#   inflating: Dataset/Images/94/14.jpg
#   inflating: Dataset/Images/94/2.jpg
#   inflating: Dataset/Images/94/3.jpg
#   inflating: Dataset/Images/94/4.jpg
#   inflating: Dataset/Images/94/5.jpg
#   inflating: Dataset/Images/94/6.jpg
#   inflating: Dataset/Images/94/7.jpg
#   inflating: Dataset/Images/94/8.jpg
#   inflating: Dataset/Images/94/9.jpg
#    creating: Dataset/Images/95/
#   inflating: Dataset/Images/95/1.jpg
#   inflating: Dataset/Images/95/10.jpg
#   inflating: Dataset/Images/95/11.jpg
#   inflating: Dataset/Images/95/12.jpg
#   inflating: Dataset/Images/95/13.jpg
#   inflating: Dataset/Images/95/14.jpg
#   inflating: Dataset/Images/95/2.jpg
#   inflating: Dataset/Images/95/3.jpg
#   inflating: Dataset/Images/95/4.jpg
#   inflating: Dataset/Images/95/5.jpg
#   inflating: Dataset/Images/95/6.jpg
#   inflating: Dataset/Images/95/7.jpg
#   inflating: Dataset/Images/95/8.jpg
#   inflating: Dataset/Images/95/9.jpg
#    creating: Dataset/Images/96/
#   inflating: Dataset/Images/96/1.jpg
#   inflating: Dataset/Images/96/10.jpg
#   inflating: Dataset/Images/96/11.jpg
#   inflating: Dataset/Images/96/12.jpg
#   inflating: Dataset/Images/96/13.jpg
#   inflating: Dataset/Images/96/14.jpg
#   inflating: Dataset/Images/96/2.jpg
#   inflating: Dataset/Images/96/3.jpg
#   inflating: Dataset/Images/96/4.jpg
#   inflating: Dataset/Images/96/5.jpg
#   inflating: Dataset/Images/96/6.jpg
#   inflating: Dataset/Images/96/7.jpg
#   inflating: Dataset/Images/96/8.jpg
#   inflating: Dataset/Images/96/9.jpg
#    creating: Dataset/Images/97/
#   inflating: Dataset/Images/97/1.jpg
#   inflating: Dataset/Images/97/10.jpg
#   inflating: Dataset/Images/97/11.jpg
#   inflating: Dataset/Images/97/12.jpg
#   inflating: Dataset/Images/97/13.jpg
#   inflating: Dataset/Images/97/14.jpg
#   inflating: Dataset/Images/97/2.jpg
#   inflating: Dataset/Images/97/3.jpg
#   inflating: Dataset/Images/97/4.jpg
#   inflating: Dataset/Images/97/5.jpg
#   inflating: Dataset/Images/97/6.jpg
#   inflating: Dataset/Images/97/7.jpg
#   inflating: Dataset/Images/97/8.jpg
#   inflating: Dataset/Images/97/9.jpg
#    creating: Dataset/Images/98/
#   inflating: Dataset/Images/98/1.jpg
#   inflating: Dataset/Images/98/10.jpg
#   inflating: Dataset/Images/98/11.jpg
#   inflating: Dataset/Images/98/12.jpg
#   inflating: Dataset/Images/98/13.jpg
#   inflating: Dataset/Images/98/14.jpg
#   inflating: Dataset/Images/98/2.jpg
#   inflating: Dataset/Images/98/3.jpg
#   inflating: Dataset/Images/98/4.jpg
#   inflating: Dataset/Images/98/5.jpg
#   inflating: Dataset/Images/98/6.jpg
#   inflating: Dataset/Images/98/7.jpg
#   inflating: Dataset/Images/98/8.jpg
#   inflating: Dataset/Images/98/9.jpg
#    creating: Dataset/Images/99/
#   inflating: Dataset/Images/99/1.jpg
#   inflating: Dataset/Images/99/10.jpg
#   inflating: Dataset/Images/99/11.jpg
#   inflating: Dataset/Images/99/12.jpg
#   inflating: Dataset/Images/99/13.jpg
#   inflating: Dataset/Images/99/14.jpg
#   inflating: Dataset/Images/99/2.jpg
#   inflating: Dataset/Images/99/3.jpg
#   inflating: Dataset/Images/99/4.jpg
#   inflating: Dataset/Images/99/5.jpg
#   inflating: Dataset/Images/99/6.jpg
#   inflating: Dataset/Images/99/7.jpg
#   inflating: Dataset/Images/99/8.jpg
#   inflating: Dataset/Images/99/9.jpg
# --2025-12-29 13:28:38--  https://cloud.tsinghua.edu.cn/f/860a9afb257f4d5180be/?dl=1
# Resolving cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)... 101.6.15.69, 2402:f000:1:402:101:6:15:69
# Connecting to cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)|101.6.15.69|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cloud.tsinghua.edu.cn/seafhttp/files/cf4401cd-0324-4e9e-8b07-84ffa1174596/ViT-B-32.pkl [following]
# --2025-12-29 13:28:39--  https://cloud.tsinghua.edu.cn/seafhttp/files/cf4401cd-0324-4e9e-8b07-84ffa1174596/ViT-B-32.pkl
# Reusing existing connection to cloud.tsinghua.edu.cn:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605144749 (577M) [application/octet-stream]
# Saving to: ‘ViT-B-32.pkl’
#
# ViT-B-32.pkl        100%[===================>] 577.11M  2.91MB/s    in 3m 16s
#
# 2025-12-29 13:31:55 (2.94 MB/s) - ‘ViT-B-32.pkl’ saved [605144749/605144749]

# %% [markdown]
# ### 自然语言的切分词
#
# 在这个部分中，`tokenize`函数能够将`N`个字符串转换为一个大小为`[N, context_length]`的`Var`张量。

# %%
def bytes_to_unicode():
    bs = list(range(ord("!"),
                    ord("~") + 1)) + list(range(
                        ord("¡"),
                        ord("¬") + 1)) + list(range(ord("®"),
                                                    ord("ÿ") + 1))
    cs = bs[:]
    n = 0
    for b in range(2**8):
        if b not in bs:
            bs.append(b)
            cs.append(2**8 + n)
            n += 1
    cs = [chr(n) for n in cs]
    return dict(zip(bs, cs))

def get_pairs(word):
    pairs = set()
    prev_char = word[0]
    for char in word[1:]:
        pairs.add((prev_char, char))
        prev_char = char
    return pairs

def basic_clean(text):
    text = ftfy.fix_text(text)
    text = html.unescape(html.unescape(text))
    return text.strip()

def whitespace_clean(text):
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()
    return text

class SimpleTokenizer(object):
    def __init__(self, bpe_path):
        self.byte_encoder = bytes_to_unicode()
        self.byte_decoder = {v: k for k, v in self.byte_encoder.items()}
        merges = gzip.open(bpe_path).read().decode("utf-8").split('\n')
        merges = merges[1:49152 - 256 - 2 + 1]
        merges = [tuple(merge.split()) for merge in merges]
        vocab = list(bytes_to_unicode().values())
        vocab = vocab + [v + '</w>' for v in vocab]
        for merge in merges:
            vocab.append(''.join(merge))
        vocab.extend(['<|startoftext|>', '<|endoftext|>'])
        self.encoder = dict(zip(vocab, range(len(vocab))))
        self.decoder = {v: k for k, v in self.encoder.items()}
        self.bpe_ranks = dict(zip(merges, range(len(merges))))
        self.cache = {
            '<|startoftext|>': '<|startoftext|>',
            '<|endoftext|>': '<|endoftext|>'
        }
        self.pat = re.compile(
            r"""<\|startoftext\|>|<\|endoftext\|>|'s|'t|'re|'ve|'m|'ll|'d|[\p{L}]+|[\p{N}]|[^\s\p{L}\p{N}]+""",
            re.IGNORECASE)

    def bpe(self, token):
        if token in self.cache:
            return self.cache[token]
        word = tuple(token[:-1]) + (token[-1] + '</w>', )
        pairs = get_pairs(word)

        if not pairs:
            return token + '</w>'

        while True:
            bigram = min(
                pairs, key=lambda pair: self.bpe_ranks.get(pair, float('inf')))
            if bigram not in self.bpe_ranks:
                break
            first, second = bigram
            new_word = []
            i = 0
            while i < len(word):
                try:
                    j = word.index(first, i)
                    new_word.extend(word[i:j])
                    i = j
                except:
                    new_word.extend(word[i:])
                    break

                if word[i] == first and i < len(word) - 1 and word[
                        i + 1] == second:
                    new_word.append(first + second)
                    i += 2
                else:
                    new_word.append(word[i])
                    i += 1
            new_word = tuple(new_word)
            word = new_word
            if len(word) == 1:
                break
            else:
                pairs = get_pairs(word)
        word = ' '.join(word)
        self.cache[token] = word
        return word

    def encode(self, text):
        bpe_tokens = []
        text = whitespace_clean(basic_clean(text)).lower()
        for token in re.findall(self.pat, text):
            token = ''.join(self.byte_encoder[b]
                            for b in token.encode('utf-8'))
            bpe_tokens.extend(self.encoder[bpe_token]
                              for bpe_token in self.bpe(token).split(' '))
        return bpe_tokens

    def decode(self, tokens):
        text = ''.join([self.decoder[token] for token in tokens])
        text = bytearray([self.byte_decoder[c] for c in text
                          ]).decode('utf-8',
                                    errors="replace").replace('</w>', ' ')
        return text

_tokenizer = SimpleTokenizer("bpe_simple_vocab_16e6.txt.gz")

def tokenize(texts: Union[str, List[str]],
             context_length: int = 77,
             truncate: bool = False):
    if isinstance(texts, str):
        texts = [texts]

    sot_token = _tokenizer.encoder["<|startoftext|>"]
    eot_token = _tokenizer.encoder["<|endoftext|>"]
    all_tokens = [[sot_token] + _tokenizer.encode(text) + [eot_token]
                  for text in texts]

    result = jt.zeros((len(all_tokens), context_length), dtype=jt.int64)

    for i, tokens in enumerate(all_tokens):
        if len(tokens) > context_length:
            if truncate:
                tokens = tokens[:context_length]
                tokens[-1] = eot_token
            else:
                raise RuntimeError(
                    f"Input {texts[i]} is too long for context length {context_length}"
                )
        result[i, :len(tokens)] = jt.Var(tokens)

    return result

# %% [markdown]
# ### 注意力层
#
# 这个部分是简化实现的注意力层。

# %%
class MultiheadAttention(Module):
    def __init__(self, embed_dim, num_heads) -> None:
        super().__init__()
        self.embed_dim = embed_dim

        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        assert self.head_dim * num_heads == self.embed_dim, "embed_dim must be divisible by num_heads"

        self.in_proj_weight = jt.empty((3 * embed_dim, embed_dim), dtype=jt.float32)
        self.in_proj_bias = jt.empty(3 * embed_dim, dtype=jt.float32)

        self.out_proj = Linear(embed_dim, embed_dim)

    def execute(self, x: Var, attn_mask: Optional[Var] = None) -> Var:
        # set up shape vars
        tgt_len, bsz, embed_dim = x.shape
        num_heads = self.num_heads
        head_dim = embed_dim // num_heads
        assert embed_dim == self.embed_dim

        proj = matmul_transpose(x, self.in_proj_weight) + self.in_proj_bias
        proj = jt.reshape(proj, (tgt_len, bsz, 3, embed_dim))
        q, k, v = proj[:, :, 0, :], proj[:, :, 1, :], proj[:, :, 2, :]

        q = q.view(tgt_len, bsz, num_heads, head_dim).permute(1, 2, 0, 3)
        k = k.view(tgt_len, bsz, num_heads, head_dim).permute(1, 2, 0, 3)
        v = v.view(tgt_len, bsz, num_heads, head_dim).permute(1, 2, 0, 3)
        # [bsz, num_heads, tgt_len, head_dim]

        attn_weight = jt.matmul(q, k.transpose(-2, -1) / math.sqrt(head_dim))
        if attn_mask is not None:
            attn_mask = jt.reshape(attn_mask, (1, 1, tgt_len, tgt_len))
            attn_weight += attn_mask
        # [bsz, num_heads, tgt_len, tgt_len]
        attn_weight = softmax(attn_weight, dim=-1)
        attn_output = jt.matmul(attn_weight, v)
        # [bsz, num_heads, tgt_len, head_dim]

        attn_output = attn_output.permute(2, 0, 1, 3).reshape(bsz * tgt_len, embed_dim)

        attn_output = self.out_proj(attn_output)
        attn_output = attn_output.reshape(tgt_len, bsz, embed_dim)
        return attn_output

class QuickGELU(nn.Module):
    def execute(self, x):
        return x * jt.sigmoid(1.702 * x)

class MLP(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        self.c_fc = nn.Linear(d_model, d_model * 4)
        self.gelu = QuickGELU()
        self.c_proj = nn.Linear(d_model * 4, d_model)

    def execute(self, x):
        return self.c_proj(self.gelu(self.c_fc(x)))

class ResidualAttentionBlock(nn.Module):
    def __init__(self, d_model, n_head, attn_mask):
        super().__init__()

        self.attn = MultiheadAttention(d_model, n_head)
        self.ln_1 = nn.LayerNorm(d_model)
        self.mlp = MLP(d_model)
        self.ln_2 = nn.LayerNorm(d_model)
        self.attn_mask = attn_mask

    def attention(self, x):
        assert self.attn_mask is None or self.attn_mask.dtype == x.dtype
        return self.attn(x, attn_mask=self.attn_mask)

    def execute(self, x):
        x = x + self.attention(self.ln_1(x))
        x = x + self.mlp(self.ln_2(x))
        return x

# %% [markdown]
# ### Vision Transformer
#
# 原始的Vision Transformer的结构如下图所示：
# ![](imgs/ViT.png)
#
# 实际实现中后续的MLP Head被替换为了一个简单的投影。
#
# 在这个部分中，你需要实现TODO(1)，完成图像切块、添加额外的`Class Embedding`以及添加`Position Embedding`

# %%
class Transformer(nn.Module):
    def __init__(self, width, layers, heads, attn_mask=None):
        super().__init__()
        self.width = width
        self.layers = layers
        self.resblocks = nn.Sequential(*[
            ResidualAttentionBlock(width, heads, attn_mask)
            for _ in range(layers)
        ])

    def execute(self, x):
        return self.resblocks(x)

class VisionTransformer(nn.Module):
    def __init__(self, input_resolution: int, patch_size: int, width: int,
                 layers: int, heads: int, output_dim: int):
        super().__init__()
        self.input_resolution = input_resolution
        self.output_dim = output_dim
        self.conv1 = nn.Conv2d(in_channels=3,
                               out_channels=width,
                               kernel_size=patch_size,
                               stride=patch_size,
                               bias=False)

        scale = width**-0.5
        self.class_embedding = scale * jt.randn((width))
        self.positional_embedding = scale * jt.randn(
            ((input_resolution // patch_size)**2 + 1, width))
        self.ln_pre = nn.LayerNorm(width)

        self.transformer = Transformer(width, layers, heads)

        self.ln_post = nn.LayerNorm(width)
        self.proj = scale * jt.randn((width, output_dim))

    def execute(self, x:jt.Var):
        """VisionTransformer forward

        Args:
            x (jt.Var): Input image with shape [B, C, H, W] (B, 3, 224, 224)

        Returns:
            jt.Var: Output image feature with shape [B, output_dim]
        """
        # TODO(1): Convert the image into a sequence.
        # Your code starts here

        # step1: use conv1 to convert x into a var with shape [B, width, grid, grid],
        # where grid == H // patch_size == W // patch_size
        x = self.conv1(x)

        # step2: reshape and permute x into a var with shape [B, grid ** 2, width]
        B, width, grid_h, grid_w = x.shape
        x = x.reshape(B, width, -1).permute(0, 2, 1)  

        # step3: concat class_embedding (with shape [width,]) and x,
        # so that the size of x becomes [B, 1 + grid ** 2, width]
        class_embedding = self.class_embedding.unsqueeze(0).unsqueeze(0).expand(B, 1, -1)  
        x = jt.concat([class_embedding, x], dim=1) 

        # step4: add the posional_embedding (with shape [grid ** 2 + 1, width]) to x
        x = x + self.positional_embedding.unsqueeze(0)  # [B, 1+grid**2, width]

        # Your code ends here

        x = self.ln_pre(x)

        x = x.permute(1, 0, 2)  # NLD -> LND
        x = self.transformer(x)
        x = x.permute(1, 0, 2)  # LND -> NLD

        x = self.ln_post(x[:, 0, :])
        x = x @ self.proj

        return x

img = jt.randn(1, 3, 224, 224)
vit = VisionTransformer(224, 32, 768, 12, 768 // 64, 512)
# [1, 512]
print(vit(img).shape)
# Out:
# [1,512,]

# %% [markdown]
# ### CLIP模型
#
# 这个部分为CLIP模型的实现，它能够将文本和图像映射为特征向量。
#
# CLIP模型的预训练需要大量的资源，本次作业中会直接加载预训练好的CLIP模型。

# %%
class CLIP(nn.Module):

    def __init__(
            self,
            embed_dim: int,
            # vision
            image_resolution: int,
            vision_layers: Union[Tuple[int, int, int, int], int],
            vision_width: int,
            vision_patch_size: int,
            # text
            context_length: int,
            vocab_size: int,
            transformer_width: int,
            transformer_heads: int,
            transformer_layers: int):
        super().__init__()

        self.context_length = context_length

        vision_heads = vision_width // 64
        self.visual = VisionTransformer(input_resolution=image_resolution,
                                        patch_size=vision_patch_size,
                                        width=vision_width,
                                        layers=vision_layers,
                                        heads=vision_heads,
                                        output_dim=embed_dim)

        self.transformer = Transformer(width=transformer_width,
                                       layers=transformer_layers,
                                       heads=transformer_heads,
                                       attn_mask=self.build_attention_mask())

        self.vocab_size = vocab_size
        self.token_embedding = nn.Embedding(vocab_size, transformer_width)
        self.positional_embedding = jt.empty(
            (self.context_length, transformer_width))
        self.ln_final = nn.LayerNorm(transformer_width)

        self.text_projection = jt.empty((transformer_width, embed_dim))
        self.logit_scale = jt.ones([]) * np.log(1 / 0.07)

    def build_attention_mask(self):
        mask = jt.empty((self.context_length, self.context_length))
        mask.fill_(float("-inf"))
        mask = jt.triu(mask, 1)  # zero out the lower diagonal
        return mask

    @property
    def dtype(self):
        return self.visual.conv1.weight.dtype

    def encode_image(self, image):
        return self.visual(image)

    def encode_text(self, text):
        x = self.token_embedding(text)

        x = x + self.positional_embedding
        x = x.permute(1, 0, 2)  # NLD -> LND
        x = self.transformer(x)
        x = x.permute(1, 0, 2)  # LND -> NLD
        x = self.ln_final(x)

        # x.shape = [batch_size, n_ctx, transformer.width]
        # take features from the eot embedding (eot_token is the highest number in each sequence)
        x = x[jt.arange(x.shape[0]),
              text.argmax(dim=-1)[0]] @ self.text_projection
        return x

def build_model(state_dict: dict):
    model = CLIP(
        embed_dim=512,
        image_resolution=224, vision_layers=12, vision_width=768, vision_patch_size=32,
        context_length=77, vocab_size=49408,
        transformer_width=512, transformer_heads=8, transformer_layers=12
    )

    for key in ["input_resolution", "context_length", "vocab_size"]:
        if key in state_dict:
            del state_dict[key]

    model.load_parameters(state_dict)
    model.eval()

    return model

# %% [markdown]
# ### 模型加载与数据预处理

# %%
def _resize(img:Image.Image, size, mode):
    w, h = img.size

    short, long = (w, h) if w <= h else (h, w)
    if short == size:
        return img

    new_short, new_long = size, int(size * long / short)
    new_w, new_h = (new_short, new_long) if w <= h else (new_long,
                                                            new_short)
    size = (new_h, new_w)
    return resize(img, size, mode)

def _to_tensor(data):
    data = np.asarray(data)
    if len(data.shape) < 3:
        data = np.expand_dims(data, -1)
    return jt.Var(data)

def _convert_image_to_rgb(image):
    return image.convert("RGB")

def _transform(n_px):
    return Compose([
        partial(_resize, size=n_px, mode=Image.BICUBIC),
        CenterCrop(n_px),
        _convert_image_to_rgb,
        ImageNormalize((0.48145466, 0.4578275, 0.40821073),
                       (0.26862954, 0.26130258, 0.27577711)),
        _to_tensor
    ])

def load(name):
    state_dict = jt.load(name)

    model = build_model(state_dict)
    return model, _transform(model.visual.input_resolution)

clip_model, preprocess = load("ViT-B-32.pkl")
# Out:
# Compiling Operators(1/1) used: 2.45s eta:    0s

# %%
class CLIPDataset(Dataset):
    def __init__(self, root, transform, allowed_names:set, batch_size=16, shuffle=False, **kwargs):
        super().__init__(batch_size, shuffle, **kwargs)
        self.root = root
        self.transform = transform
        self.classes = sorted([int(d.name) for d in os.scandir(root) if d.is_dir()])
        self.classes = [str(n) for n in self.classes]
        self.class_to_idx = {v:k for k,v in enumerate(self.classes)}
        self.imgs = []
        image_exts = set(('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff'))
        
        for i, class_name in enumerate(self.classes):
            class_dir = os.path.join(root, class_name)
            assert class_name == str(i), "{} != {}".format(class_name, str(i))
            for dname, _, fnames in sorted(os.walk(class_dir, followlinks=True)):
                for fname in sorted(fnames):
                    if os.path.splitext(fname)[-1].lower() in image_exts:
                        if os.path.splitext(fname)[0].lower() not in allowed_names:
                            continue
                        path = os.path.join(class_dir, fname)
                        self.imgs.append((path, i))
        self.set_attrs(total_len=len(self.imgs))
        
    def __getitem__(self, k):
        with open(self.imgs[k][0], 'rb') as f:
            img = Image.open(f).convert('RGB')
            if self.transform:
                img = self.transform(img)
            return img, self.imgs[k][1]

train_names = set([str(i) for i in range(1, 5)])
val_names = set([str(i) for i in range(5, 15)])
train_dataset = CLIPDataset('Dataset/Images/', transform=preprocess, allowed_names=train_names, batch_size=16, shuffle=True)
val_dataset = CLIPDataset('Dataset/Images/', transform=preprocess, allowed_names=val_names, batch_size=16, shuffle=False)

# %% [markdown]
# ### 图像特征生成与评估
# 本次作业中，我们使用TOP1准确率和TOP5准确率来评估方法进行图像分类的能力。
#
# 其中，TOP1准确率为 分类正确图像数量/图片总数，TOP5准确率为 预测概率最高的5个类别中有正确类别的图像数量/图片总数。

# %%
def evaluate(predictions:np.ndarray, labels:np.ndarray, return_result=False):
    assert predictions.shape[0] == labels.shape[0]
    ranks = predictions.argsort(-1)
    top_5 = ranks[:, -1:-6:-1]
    top_1 = top_5[:, :1]
    target = labels[:, np.newaxis]
    top_5_acc = np.sum(top_5 == target, axis=-1) > 0
    top_1_acc = np.sum(top_1 == target, axis=-1) > 0
    top_5_acc = np.sum(top_5_acc) / top_5_acc.shape[0]
    top_1_acc = np.sum(top_1_acc) / top_1_acc.shape[0]
    print("Top1 Acc: {:.3f} %, Top5 Acc: {:.3f} %".format(top_1_acc * 100, top_5_acc * 100))
    if return_result:
        return top_1_acc, top_5_acc

def get_image_features(dataset, model:CLIP):
    features, labels = [], []
    for img, label in tqdm(dataset, total=len(dataset)):
        feature = model.encode_image(img)
        features.append(feature)
        labels.append(label)
    features = jt.concat(features).numpy()
    labels = jt.concat(labels).numpy()
    return features, labels

def normalize(features):
    return features / np.linalg.norm(features, ord=2, axis=-1, keepdims=True)

train_features, train_labels = get_image_features(train_dataset, clip_model)
val_features, val_labels = get_image_features(val_dataset, clip_model)
# Out:
#  78%|███████▊  | 73/94 [00:07<00:02,  9.41it/s]
# Compiling Operators(3/42) used: 3.31s eta: 43.1s 8/42) used: 4.32s eta: 18.4s 10/42) used: 5.33s eta: 17.1s 11/42) used: 6.34s eta: 17.9s 16/42) used: 7.34s eta: 11.9s 19/42) used: 9.35s eta: 11.3s 21/42) used: 10.4s eta: 10.4s 23/42) used: 11.4s eta: 9.39s 27/42) used: 12.4s eta: 6.89s 28/42) used: 13.4s eta: 6.71s 30/42) used: 14.4s eta: 5.77s 33/42) used: 15.4s eta: 4.21s 37/42) used: 16.4s eta: 2.22s 38/42) used: 17.4s eta: 1.84s 40/42) used: 18.4s eta: 0.922s 41/42) used: 19.5s eta: 0.474s 42/42) used: 22.5s eta:    0s
# 100%|██████████| 94/94 [00:33<00:00,  2.78it/s]
#
# Compiling Operators(2/3) used: 3.31s eta: 1.66s 3/3) used: 4.32s eta:    0s
#
# Compiling Operators(1/1) used: 2.48s eta:    0s
# 100%|██████████| 234/234 [00:26<00:00,  8.96it/s]

# %% [markdown]
# ### Linear Probe
# Linear Probe方法不使用文本特征，而是直接利用逻辑回归对图像特征进行分类。

# %%
classifier = LogisticRegression(random_state=0,
                                C=8.960,
                                max_iter=1000,
                                verbose=1)
classifier.fit(normalize(train_features), train_labels)
predictions = classifier.predict_proba(normalize(val_features))
evaluate(predictions, val_labels)
# Out:
# Top1 Acc: 64.492 %, Top5 Acc: 86.471 %
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.4s finished

# %% [markdown]
# ### Zero-shot分类
# 通过比较类别文本特征和图片特征的相似度，模型无需进行额外训练，就可以预测图片属于那一份文本对应的类别。
#
# 在这个部分中，你需要实现`TODO(2)`，通过比较文本特征和图片特征进行图像分类。
#
# 具体来说，文本特征和图片特征之间的比较是通过计算它们的余弦相似度实现的。余弦相似度的计算公式为：
# $$
# cosine\_similarity(A, B) = \frac{A\cdot B}{|A|\cdot |B|}
# $$
# 其中$A$和$B$是形状相同的一维向量，$\cdot$ 代表点积/标量乘法。

# %%
classes = open('Dataset/classes.txt').read().splitlines()
new_classes = []
basenames = ['Animal', 'Thu-dog', 'Caltech-101', 'Food-101']
for c in classes:
    assert len(new_classes) == int(c.split(' ')[1])
    c = c.split(' ')[0]
    for bname in basenames:
        if c.startswith(bname):
            c = c[len(bname)+1:]
    c = 'a photo of ' + c
    new_classes.append(c)

# TODO(2): Perform image classification by directly comparing image features with text features.
# Your code starts here
# step1: tokenize the new_classes
text_tokens = tokenize(new_classes)

# step2: encode the text
text_features = clip_model.encode_text(text_tokens)
text_features_norm = normalize(text_features.numpy())

# step3: generate prediction results by compare features.
# Note: predictions should be a Numpy array with shape [N_imgs, N_classes],
# where predictions[i, j] is the cosine similarity between the image i and the classification j.
val_features_norm = normalize(val_features)
predictions = val_features_norm @ text_features_norm.T  

# Your code ends here
evaluate(predictions, val_labels)
# Out:
# Compiling Operators(3/11) used: 3.31s eta: 8.83s 8/11) used: 4.32s eta: 1.62s 10/11) used: 5.32s eta: 0.532s 11/11) used: 6.33s eta:    0s
# Top1 Acc: 67.888 %, Top5 Acc: 88.102 %

# %% [markdown]
# ### 使用Adapter进行微调
# 为了能够同时使用文本特征以及训练数据，我们添加一个参数量很小的可训练的Adapter，对图像特征进行微调。
#
# 在这个部分中，你需要实现`TODO(3)`。
#
# 相较于Zero-shot部分，其不同之处在于：
# 1. 需要使用Adapter处理图像特征
# 2. 需要乘上`logit_scale`用于训练。

# %%
class AdapterDataset(Dataset):
    def __init__(self, features, labels, batch_size=16, shuffle=True, **kwargs):
        super().__init__(batch_size, shuffle, **kwargs)
        self.features = jt.array(features)
        self.labels = jt.array(labels)
        self.total_len = features.shape[0]

    def __getitem__(self, index):
        return self.features[index], self.labels[index]

class Adapter(Module):
    def __init__(self, in_channel, hidden_channel, alpha):
        self.fc = nn.Sequential(
            nn.Linear(in_channel, hidden_channel),
            nn.ReLU(),
            nn.Linear(hidden_channel, in_channel),
            nn.ReLU(),
        )
        self.alpha = alpha

    def execute(self, feature):
        return feature * self.alpha + self.fc(feature) * (1 - self.alpha)

class CLIPAdapter(Module):
    def __init__(self, in_channel, hidden_channel, logit_scale, alpha=0.2):
        self.image_adapter = Adapter(in_channel, hidden_channel, alpha=alpha)
        self.logit_scale = logit_scale.exp()
        self.logit_scale.stop_grad()

    def execute(self, image_feature, text_feature):
        # TODO(3): Execution of CLIP Adapter
        # Your code starts here
        # step1: process the image_feature with image_adapter
        adapted_image_feature = self.image_adapter(image_feature)

        # step2: normalize the image_feature and the text_feature
        image_feature_norm = adapted_image_feature / jt.norm(adapted_image_feature, dim=1, keepdim=True)
        text_feature_norm = text_feature / jt.norm(text_feature, dim=1, keepdim=True)

        # step3: Compute the similarity between `image_feature` and `text_feature`
        # using using matrix multiplication, and scale the result by the factor `logit_scale``
        logits = self.logit_scale * jt.matmul(image_feature_norm, text_feature_norm.transpose(1, 0))

        # Your code ends here
        return logits

def train_adapter(model:CLIP, train_features, train_labels, text_features, n_epochs=5):
    dataset = AdapterDataset(train_features, train_labels, shuffle=True)
    adapter = CLIPAdapter(512, 128, model.logit_scale)
    adapter.train()
    optimizer = jt.optim.Adam(adapter.image_adapter.parameters(), lr=0.0003)
    text_features = jt.array(text_features)
    for e_id in range(n_epochs):
        for img, text in dataset:
            pred = adapter(img, text_features)
            loss = nn.cross_entropy_loss(pred, text)
            loss.sync()
            optimizer.step(loss)
    return adapter

def run_adapter():
    adapter = train_adapter(clip_model, train_features, train_labels, text_features)
    adapter.eval()
    with jt.no_grad():
        predictions = adapter(jt.array(val_features), jt.array(text_features)).numpy()
    top1, _ = evaluate(predictions, val_labels, return_result=True)
    return top1

baselines = [run_adapter() for _ in range(10)]
print("Mean Top1: {:.3f} %".format(sum(baselines) / 10 * 100))
# Out:
# Compiling Operators(4/16) used: 3.31s eta: 9.94s 10/16) used: 4.32s eta: 2.59s 14/16) used: 7.33s eta: 1.05s 16/16) used: 8.34s eta:    0s
#
# Compiling Operators(1/16) used: 3.31s eta: 49.7s 9/16) used: 4.32s eta: 3.36s 10/16) used: 5.33s eta:  3.2s 11/16) used: 7.34s eta: 3.33s 14/16) used: 8.34s eta: 1.19s 15/16) used: 9.35s eta: 0.623s 16/16) used: 11.4s eta:    0s
#
# Compiling Operators(3/3) used: 4.31s eta:    0s
# Top1 Acc: 70.722 %, Top5 Acc: 91.765 %
# Top1 Acc: 71.283 %, Top5 Acc: 91.765 %
# Top1 Acc: 71.283 %, Top5 Acc: 92.246 %
# Top1 Acc: 71.604 %, Top5 Acc: 92.059 %
# Top1 Acc: 71.390 %, Top5 Acc: 91.711 %
# Top1 Acc: 71.738 %, Top5 Acc: 92.273 %
# Top1 Acc: 71.096 %, Top5 Acc: 92.594 %
# Top1 Acc: 71.444 %, Top5 Acc: 92.112 %
# Top1 Acc: 71.230 %, Top5 Acc: 91.791 %
# Top1 Acc: 71.444 %, Top5 Acc: 91.845 %
# Mean Top1: 71.324 %
